# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
import pandas as pd

# Specify the engine parameter explicitly
data = pd.read_excel('/content/chennai_cars.xlsx')

# Now try to read the Excel file

# %%
data.shape #rows,columns
# Out:
# (1419, 5)

# %%
data.head()
# Out:
#                                       new_car_detail  \
# 0  {'it': 0, 'ft': 'Petrol', 'bt': 'SUV', 'km': '...
# 1  {'it': 0, 'ft': 'Petrol', 'bt': 'Minivans', 'k...
# 2  {'it': 0, 'ft': 'Petrol', 'bt': 'SUV', 'km': '...
# 3  {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 4  {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
#
#                                     new_car_overview  \
# 0  {'heading': 'Car overview', 'top': [{'key': 'R...
# 1  {'heading': 'Car overview', 'top': [{'key': 'R...
# 2  {'heading': 'Car overview', 'top': [{'key': 'R...
# 3  {'heading': 'Car overview', 'top': [{'key': 'R...
# 4  {'heading': 'Car overview', 'top': [{'key': 'R...
#
#                                      new_car_feature  \
# 0  {'heading': 'Features', 'top': [{'value': 'Pow...
# 1  {'heading': 'Features', 'top': [{'value': 'Low...
# 2  {'heading': 'Features', 'top': [{'value': 'Pow...
# 3  {'heading': 'Features', 'top': [{'value': 'Pow...
# 4  {'heading': 'Features', 'top': [{'value': 'Pow...
#
#                                        new_car_specs  \
# 0  {'heading': 'Specifications', 'top': [{'key': ...
# 1  {'heading': 'Specifications', 'top': [{'key': ...
# 2  {'heading': 'Specifications', 'top': [{'key': ...
# 3  {'heading': 'Specifications', 'top': [{'key': ...
# 4  {'heading': 'Specifications', 'top': [{'key': ...
#
#                                            car_links
# 0  https://www.cardekho.com/used-car-details/used...
# 1  https://www.cardekho.com/buy-used-car-details/...
# 2  https://www.cardekho.com/used-car-details/used...
# 3  https://www.cardekho.com/buy-used-car-details/...
# 4  https://www.cardekho.com/used-car-details/used...

# %%
data.new_car_detail[0]
# Out:
# "{'it': 0, 'ft': 'Petrol', 'bt': 'SUV', 'km': '20,000', 'transmission': 'Automatic', 'ownerNo': 1, 'owner': '1st Owner', 'oem': 'Kia', 'model': 'Kia Sonet', 'modelYear': 2022, 'centralVariantId': 8654, 'variantName': 'Turbo DCT Anniversary Edition', 'price': '₹ 11.50 Lakh', 'priceActual': '', 'priceSaving': '', 'priceFixedText': None, 'trendingText': {'imgUrl': 'https://stimg.cardekho.com/used-cars/common/icons/trending.svg', 'heading': 'Trending Car!', 'desc': 'High chances of sale in next 6 days'}}"

# %%
 # package to convert string to dictionary
import numpy as np
import ast
ast.literal_eval(data.new_car_detail[0])['ft']
# Out:
# 'Petrol'

# %%
collection_name=[]
for i in data['new_car_detail'].values:
  if i == i:
    collection_name.append(ast.literal_eval(i)['ft'])

    continue

# %%
data["fuel type"]=collection_name  #create a new column

# %%
collection_name=[]
for i in data['new_car_detail'].values:
  if i == i:
    collection_name.append(ast.literal_eval(i)['bt'])

    continue

# %%
data["Body type"]=collection_name  #create a new column

# %%
collection_name=[]
for i in data['new_car_detail'].values:
  if i == i:
    collection_name.append(ast.literal_eval(i)['km'])

    continue

# %%
data["Kilometers driven"]=collection_name  #create a new column

# %%
collection_name=[]
for i in data['new_car_detail'].values:
  if i == i:
    collection_name.append(ast.literal_eval(i)['transmission'])

    continue

# %%
data["Transmission type"]=collection_name  #create a new column

# %%
collection_name=[]
for i in data['new_car_detail'].values:
  if i == i:
    collection_name.append(ast.literal_eval(i)['ownerNo'])

    continue

# %%
data["Number of previous owners"]=collection_name  #create a new column

# %%
collection_name=[]
for i in data['new_car_detail'].values:
  if i == i:
    collection_name.append(ast.literal_eval(i)['owner'])

    continue

# %%
data["Ownership details"]=collection_name  #create a new column

# %%
collection_name=[]
for i in data['new_car_detail'].values:
  if i == i:
    collection_name.append(ast.literal_eval(i)['oem'])

    continue

# %%
data["Original Equipment Manufacturer"]=collection_name  #create a new column

# %%
collection_name=[]
for i in data['new_car_detail'].values:
  if i == i:
    collection_name.append(ast.literal_eval(i)['model'])

    continue

# %%
data["Car model"]=collection_name  #create a new column

# %%
collection_name=[]
for i in data['new_car_detail'].values:
  if i == i:
    collection_name.append(ast.literal_eval(i)['modelYear'])

    continue

# %%
data["Year of car manufacture"]=collection_name  #create a new column

# %%
collection_name=[]
for i in data['new_car_detail'].values:
  if i == i:
    collection_name.append(ast.literal_eval(i)['centralVariantId'])

    continue

# %%
data["Central variant ID"]=collection_name  #create a new column

# %%
collection_name=[]
for i in data['new_car_detail'].values:
  if i == i:
    collection_name.append(ast.literal_eval(i)['variantName'])

    continue

# %%
data["Variant name"]=collection_name  #create a new column

# %%
collection_name=[]
for i in data['new_car_detail'].values:
  if i == i:
    collection_name.append(ast.literal_eval(i)['price'])

    continue

# %%
data["Price of the used car"]=collection_name  #create a new column

# %%
collection_name=[]
for i in data['new_car_detail'].values:
  if i == i:
    collection_name.append(ast.literal_eval(i)['priceActual'])

    continue

# %%
data["Actual price"]=collection_name  #create a new column

# %%
collection_name=[]
for i in data['new_car_detail'].values:
  if i == i:
    collection_name.append(ast.literal_eval(i)['priceSaving'])

    continue

# %%
data["Price saving "]=collection_name  #create a new column

# %%
collection_name=[]
for i in data['new_car_detail'].values:
  if i == i:
    collection_name.append(ast.literal_eval(i)['priceFixedText'])

    continue

# %%
data["Fixed price details"]=collection_name  #create a new column

# %%
collection_name=[]
for i in data['new_car_detail'].values:
  if i == i:
    collection_name.append(ast.literal_eval(i)['trendingText'])

    continue

# %%
data["Trending car information"]=collection_name  #create a new column

# %%
data = data.drop(columns = ['new_car_detail'])

# %%
data
# Out:
#                                        new_car_overview  \
# 0     {'heading': 'Car overview', 'top': [{'key': 'R...
# 1     {'heading': 'Car overview', 'top': [{'key': 'R...
# 2     {'heading': 'Car overview', 'top': [{'key': 'R...
# 3     {'heading': 'Car overview', 'top': [{'key': 'R...
# 4     {'heading': 'Car overview', 'top': [{'key': 'R...
# ...                                                 ...
# 1414  {'heading': 'Car overview', 'top': [{'key': 'R...
# 1415  {'heading': 'Car overview', 'top': [{'key': 'R...
# 1416  {'heading': 'Car overview', 'top': [{'key': 'R...
# 1417  {'heading': 'Car overview', 'top': [{'key': 'R...
# 1418  {'heading': 'Car overview', 'top': [{'key': 'R...
#
#                                         new_car_feature  \
# 0     {'heading': 'Features', 'top': [{'value': 'Pow...
# 1     {'heading': 'Features', 'top': [{'value': 'Low...
# 2     {'heading': 'Features', 'top': [{'value': 'Pow...
# 3     {'heading': 'Features', 'top': [{'value': 'Pow...
# 4     {'heading': 'Features', 'top': [{'value': 'Pow...
# ...                                                 ...
# 1414  {'heading': 'Features', 'top': [{'value': 'Pow...
# 1415  {'heading': 'Features', 'top': [{'value': 'Pow...
# 1416  {'heading': 'Features', 'top': [{'value': 'Pow...
# 1417  {'heading': 'Features', 'top': [{'value': 'Pow...
# 1418  {'heading': 'Features', 'top': [{'value': 'Pow...
#
#                                           new_car_specs  \
# 0     {'heading': 'Specifications', 'top': [{'key': ...
# 1     {'heading': 'Specifications', 'top': [{'key': ...
# 2     {'heading': 'Specifications', 'top': [{'key': ...
# 3     {'heading': 'Specifications', 'top': [{'key': ...
# 4     {'heading': 'Specifications', 'top': [{'key': ...
# ...                                                 ...
# 1414  {'heading': 'Specifications', 'top': [{'key': ...
# 1415  {'heading': 'Specifications', 'top': [{'key': ...
# 1416  {'heading': 'Specifications', 'top': [{'key': ...
# 1417  {'heading': 'Specifications', 'top': [{'key': ...
# 1418  {'heading': 'Specifications', 'top': [{'key': ...
#
#                                               car_links fuel type  Body type  \
# 0     https://www.cardekho.com/used-car-details/used...    Petrol        SUV
# 1     https://www.cardekho.com/buy-used-car-details/...    Petrol   Minivans
# 2     https://www.cardekho.com/used-car-details/used...    Petrol        SUV
# 3     https://www.cardekho.com/buy-used-car-details/...    Petrol  Hatchback
# 4     https://www.cardekho.com/used-car-details/used...    Petrol  Hatchback
# ...                                                 ...       ...        ...
# 1414  https://www.cardekho.com/used-car-details/used...    Petrol  Hatchback
# 1415  https://www.cardekho.com/used-car-details/used...    Diesel        SUV
# 1416  https://www.cardekho.com/used-car-details/used...    Petrol        SUV
# 1417  https://www.cardekho.com/used-car-details/used...    Diesel        SUV
# 1418  https://www.cardekho.com/used-car-details/used...    Diesel      Sedan
#
#      Kilometers driven Transmission type  Number of previous owners  \
# 0               20,000         Automatic                          1
# 1               20,687            Manual                          1
# 2               30,000            Manual                          1
# 3               59,247            Manual                          1
# 4               50,000            Manual                          1
# ...                ...               ...                        ...
# 1414            42,891         Automatic                          1
# 1415            59,100            Manual                          1
# 1416            55,913         Automatic                          1
# 1417            65,000         Automatic                          1
# 1418            60,000         Automatic                          1
#
#      Ownership details Original Equipment Manufacturer          Car model  \
# 0            1st Owner                             Kia          Kia Sonet
# 1            1st Owner                          Maruti        Maruti Eeco
# 2            1st Owner                          Nissan     Nissan Magnite
# 3            1st Owner                         Hyundai        Hyundai i10
# 4            1st Owner                           Honda         Honda Jazz
# ...                ...                             ...                ...
# 1414         1st Owner                          Maruti       Maruti Swift
# 1415         1st Owner                         Renault     Renault Duster
# 1416         1st Owner                            Tata         Tata Nexon
# 1417         1st Owner                      Volkswagen  Volkswagen Tiguan
# 1418         1st Owner                             BMW    BMW 3 Series GT
#
#       Year of car manufacture  Central variant ID  \
# 0                        2022                8654
# 1                        2015                4025
# 2                        2021                8135
# 3                        2015                1579
# 4                        2015                1341
# ...                       ...                 ...
# 1414                     2018                6190
# 1415                     2018                5050
# 1416                     2018                6364
# 1417                     2017                5849
# 1418                     2019                6630
#
#                        Variant name Price of the used car Actual price  \
# 0     Turbo DCT Anniversary Edition          ₹ 11.50 Lakh
# 1            7 Seater Standard BSIV           ₹ 4.15 Lakh
# 2             Turbo XV Premium BSVI           ₹ 7.50 Lakh
# 3                       Sportz 1.1L           ₹ 3.98 Lakh
# 4                     1.2 VX i VTEC           ₹ 5.50 Lakh
# ...                             ...                   ...          ...
# 1414                        AMT VXI           ₹ 6.20 Lakh
# 1415                85PS Diesel RxZ           ₹ 8.90 Lakh
# 1416          1.2 Revotron XZA Plus           ₹ 8.01 Lakh
# 1417               2.0 TDI Highline          ₹ 20.50 Lakh
# 1418                          Sport          ₹ 35.75 Lakh
#
#      Price saving  Fixed price details  \
# 0                                 None
# 1                                 None
# 2                                 None
# 3                                 None
# 4                                 None
# ...            ...                 ...
# 1414                              None
# 1415                              None
# 1416                              None
# 1417                              None
# 1418                              None
#
#                                Trending car information
# 0     {'imgUrl': 'https://stimg.cardekho.com/used-ca...
# 1     {'imgUrl': 'https://stimg.cardekho.com/used-ca...
# 2     {'imgUrl': 'https://stimg.cardekho.com/used-ca...
# 3     {'imgUrl': 'https://stimg.cardekho.com/used-ca...
# 4     {'imgUrl': 'https://stimg.cardekho.com/used-ca...
# ...                                                 ...
# 1414  {'imgUrl': 'https://stimg.cardekho.com/used-ca...
# 1415  {'imgUrl': 'https://stimg.cardekho.com/used-ca...
# 1416  {'imgUrl': 'https://stimg.cardekho.com/used-ca...
# 1417  {'imgUrl': 'https://stimg.cardekho.com/used-ca...
# 1418  {'imgUrl': 'https://stimg.cardekho.com/used-ca...
#
# [1419 rows x 20 columns]

# %%
data = data.drop(columns = ['new_car_specs'])  #'new_car_overview','new_car_feature',

# %%
data = data.drop(columns = ['car_links'])

# %%
data = data.drop(columns = ['Trending car information'])

# %%
data['Location'] = 'chennai'

# %%
data
# Out:
#                                        new_car_overview  \
# 0     {'heading': 'Car overview', 'top': [{'key': 'R...
# 1     {'heading': 'Car overview', 'top': [{'key': 'R...
# 2     {'heading': 'Car overview', 'top': [{'key': 'R...
# 3     {'heading': 'Car overview', 'top': [{'key': 'R...
# 4     {'heading': 'Car overview', 'top': [{'key': 'R...
# ...                                                 ...
# 1414  {'heading': 'Car overview', 'top': [{'key': 'R...
# 1415  {'heading': 'Car overview', 'top': [{'key': 'R...
# 1416  {'heading': 'Car overview', 'top': [{'key': 'R...
# 1417  {'heading': 'Car overview', 'top': [{'key': 'R...
# 1418  {'heading': 'Car overview', 'top': [{'key': 'R...
#
#                                         new_car_feature fuel type  Body type  \
# 0     {'heading': 'Features', 'top': [{'value': 'Pow...    Petrol        SUV
# 1     {'heading': 'Features', 'top': [{'value': 'Low...    Petrol   Minivans
# 2     {'heading': 'Features', 'top': [{'value': 'Pow...    Petrol        SUV
# 3     {'heading': 'Features', 'top': [{'value': 'Pow...    Petrol  Hatchback
# 4     {'heading': 'Features', 'top': [{'value': 'Pow...    Petrol  Hatchback
# ...                                                 ...       ...        ...
# 1414  {'heading': 'Features', 'top': [{'value': 'Pow...    Petrol  Hatchback
# 1415  {'heading': 'Features', 'top': [{'value': 'Pow...    Diesel        SUV
# 1416  {'heading': 'Features', 'top': [{'value': 'Pow...    Petrol        SUV
# 1417  {'heading': 'Features', 'top': [{'value': 'Pow...    Diesel        SUV
# 1418  {'heading': 'Features', 'top': [{'value': 'Pow...    Diesel      Sedan
#
#      Kilometers driven Transmission type  Number of previous owners  \
# 0               20,000         Automatic                          1
# 1               20,687            Manual                          1
# 2               30,000            Manual                          1
# 3               59,247            Manual                          1
# 4               50,000            Manual                          1
# ...                ...               ...                        ...
# 1414            42,891         Automatic                          1
# 1415            59,100            Manual                          1
# 1416            55,913         Automatic                          1
# 1417            65,000         Automatic                          1
# 1418            60,000         Automatic                          1
#
#      Ownership details Original Equipment Manufacturer          Car model  \
# 0            1st Owner                             Kia          Kia Sonet
# 1            1st Owner                          Maruti        Maruti Eeco
# 2            1st Owner                          Nissan     Nissan Magnite
# 3            1st Owner                         Hyundai        Hyundai i10
# 4            1st Owner                           Honda         Honda Jazz
# ...                ...                             ...                ...
# 1414         1st Owner                          Maruti       Maruti Swift
# 1415         1st Owner                         Renault     Renault Duster
# 1416         1st Owner                            Tata         Tata Nexon
# 1417         1st Owner                      Volkswagen  Volkswagen Tiguan
# 1418         1st Owner                             BMW    BMW 3 Series GT
#
#       Year of car manufacture  Central variant ID  \
# 0                        2022                8654
# 1                        2015                4025
# 2                        2021                8135
# 3                        2015                1579
# 4                        2015                1341
# ...                       ...                 ...
# 1414                     2018                6190
# 1415                     2018                5050
# 1416                     2018                6364
# 1417                     2017                5849
# 1418                     2019                6630
#
#                        Variant name Price of the used car Actual price  \
# 0     Turbo DCT Anniversary Edition          ₹ 11.50 Lakh
# 1            7 Seater Standard BSIV           ₹ 4.15 Lakh
# 2             Turbo XV Premium BSVI           ₹ 7.50 Lakh
# 3                       Sportz 1.1L           ₹ 3.98 Lakh
# 4                     1.2 VX i VTEC           ₹ 5.50 Lakh
# ...                             ...                   ...          ...
# 1414                        AMT VXI           ₹ 6.20 Lakh
# 1415                85PS Diesel RxZ           ₹ 8.90 Lakh
# 1416          1.2 Revotron XZA Plus           ₹ 8.01 Lakh
# 1417               2.0 TDI Highline          ₹ 20.50 Lakh
# 1418                          Sport          ₹ 35.75 Lakh
#
#      Price saving  Fixed price details Location
# 0                                 None  chennai
# 1                                 None  chennai
# 2                                 None  chennai
# 3                                 None  chennai
# 4                                 None  chennai
# ...            ...                 ...      ...
# 1414                              None  chennai
# 1415                              None  chennai
# 1416                              None  chennai
# 1417                              None  chennai
# 1418                              None  chennai
#
# [1419 rows x 18 columns]

# %%
d1=pd.read_excel("/content/hyderabad_cars.xlsx")#read the file

# %%
d1.shape #rows,columns
# Out:
# (1483, 5)

# %%
d1.head()
# Out:
#                                       new_car_detail  \
# 0  {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 1  {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 2  {'it': 0, 'ft': 'Petrol', 'bt': 'SUV', 'km': '...
# 3  {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 4  {'it': 0, 'ft': 'Petrol', 'bt': 'SUV', 'km': '...
#
#                                     new_car_overview  \
# 0  {'heading': 'Car overview', 'top': [{'key': 'R...
# 1  {'heading': 'Car overview', 'top': [{'key': 'R...
# 2  {'heading': 'Car overview', 'top': [{'key': 'R...
# 3  {'heading': 'Car overview', 'top': [{'key': 'R...
# 4  {'heading': 'Car overview', 'top': [{'key': 'R...
#
#                                      new_car_feature  \
# 0  {'heading': 'Features', 'top': [{'value': 'Pow...
# 1  {'heading': 'Features', 'top': [{'value': 'Pow...
# 2  {'heading': 'Features', 'top': [{'value': 'Pow...
# 3  {'heading': 'Features', 'top': [{'value': 'Pow...
# 4  {'heading': 'Features', 'top': [{'value': 'Pow...
#
#                                        new_car_specs  \
# 0  {'heading': 'Specifications', 'top': [{'key': ...
# 1  {'heading': 'Specifications', 'top': [{'key': ...
# 2  {'heading': 'Specifications', 'top': [{'key': ...
# 3  {'heading': 'Specifications', 'top': [{'key': ...
# 4  {'heading': 'Specifications', 'top': [{'key': ...
#
#                                            car_links
# 0  https://www.cardekho.com/used-car-details/used...
# 1  https://www.cardekho.com/buy-used-car-details/...
# 2  https://www.cardekho.com/used-car-details/used...
# 3  https://www.cardekho.com/buy-used-car-details/...
# 4  https://www.cardekho.com/used-car-details/used...

# %%
d1.new_car_detail[0]
# Out:
# "{'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', 'km': '20,000', 'transmission': 'Automatic', 'ownerNo': 1, 'owner': '1st Owner', 'oem': 'Volkswagen', 'model': 'Volkswagen Polo', 'modelYear': 2022, 'centralVariantId': 7746, 'variantName': '1.0 TSI Highline Plus AT', 'price': '₹ 10.44 Lakh', 'priceActual': '', 'priceSaving': '', 'priceFixedText': None, 'trendingText': {'imgUrl': 'https://stimg.cardekho.com/used-cars/common/icons/trending.svg', 'heading': 'Trending Car!', 'desc': 'High chances of sale in next 6 days'}}"

# %%
collection_name=[]
for i in d1['new_car_detail'].values:
  if i == i:
    collection_name.append(ast.literal_eval(i)['ft'])

    continue

# %%
d1["fuel type"]=collection_name  #create a new column

# %%
import ast
import pandas as pd

# Assuming 'data' is your DataFrame

collection_name = []
for i in d1['new_car_detail'].values:
    if i == i:
        collection_name.append(ast.literal_eval(i).get('transmission'))

d1["Transmission type"] = collection_name

collection_name = []
for i in d1['new_car_detail'].values:
    if i == i:
        collection_name.append(ast.literal_eval(i).get('bt'))

d1["Body type"] = collection_name

collection_name = []
for i in d1['new_car_detail'].values:
    if i == i:
        collection_name.append(ast.literal_eval(i).get('km'))

d1["Kilometers driven"] = collection_name

collection_name = []
for i in d1['new_car_detail'].values:
    if i == i:
        collection_name.append(ast.literal_eval(i).get('ownerNo'))

d1["Number of previous owners"] = collection_name

collection_name = []
for i in d1['new_car_detail'].values:
    if i == i:
        collection_name.append(ast.literal_eval(i).get('owner'))

d1["Ownership details"] = collection_name

collection_name = []
for i in d1['new_car_detail'].values:
    if i == i:
        collection_name.append(ast.literal_eval(i).get('oem'))

d1["Original Equipment Manufacturer"] = collection_name


collection_name = []
for i in d1['new_car_detail'].values:
    if i == i:
        collection_name.append(ast.literal_eval(i).get('model'))

d1["Car model"] = collection_name

collection_name = []
for i in d1['new_car_detail'].values:
    if i == i:
        collection_name.append(ast.literal_eval(i).get('modelYear'))

d1["Year of car manufacture"] = collection_name

collection_name = []
for i in d1['new_car_detail'].values:
    if i == i:
        collection_name.append(ast.literal_eval(i).get('centralVariantId'))

d1[" Central variant ID"] = collection_name

collection_name = []
for i in d1['new_car_detail'].values:
    if i == i:
        collection_name.append(ast.literal_eval(i).get('variantName'))

d1["Variant name"] = collection_name

collection_name = []
for i in d1['new_car_detail'].values:
    if i == i:
        collection_name.append(ast.literal_eval(i).get('price'))

d1["Price of the used car"] = collection_name


collection_name = []
for i in d1['new_car_detail'].values:
    if i == i:
        collection_name.append(ast.literal_eval(i).get('priceActual'))

d1["Actual price"] = collection_name

collection_name = []
for i in d1['new_car_detail'].values:
    if i == i:
        collection_name.append(ast.literal_eval(i).get('priceSaving'))

d1["Price saving "] = collection_name

collection_name = []
for i in d1['new_car_detail'].values:
    if i == i:
        collection_name.append(ast.literal_eval(i).get('priceFixedText'))

d1["Fixed price details"] = collection_name

# %%
d1 = d1.drop(columns = ['new_car_specs']) #'new_car_overview','new_car_feature',

# %%
d1 = d1.drop(columns = ['car_links'])

# %%
d1 = d1.drop(columns = ['new_car_detail'])

# %%
d1['Location'] = 'Hyderabad'

# %%
d1
# Out:
#                                        new_car_overview  \
# 0     {'heading': 'Car overview', 'top': [{'key': 'R...
# 1     {'heading': 'Car overview', 'top': [{'key': 'R...
# 2     {'heading': 'Car overview', 'top': [{'key': 'R...
# 3     {'heading': 'Car overview', 'top': [{'key': 'R...
# 4     {'heading': 'Car overview', 'top': [{'key': 'R...
# ...                                                 ...
# 1478  {'heading': 'Car overview', 'top': [{'key': 'R...
# 1479  {'heading': 'Car overview', 'top': [{'key': 'R...
# 1480  {'heading': 'Car overview', 'top': [{'key': 'R...
# 1481  {'heading': 'Car overview', 'top': [{'key': 'R...
# 1482  {'heading': 'Car overview', 'top': [{'key': 'R...
#
#                                         new_car_feature fuel type  \
# 0     {'heading': 'Features', 'top': [{'value': 'Pow...    Petrol
# 1     {'heading': 'Features', 'top': [{'value': 'Pow...    Petrol
# 2     {'heading': 'Features', 'top': [{'value': 'Pow...    Petrol
# 3     {'heading': 'Features', 'top': [{'value': 'Pow...    Petrol
# 4     {'heading': 'Features', 'top': [{'value': 'Pow...    Petrol
# ...                                                 ...       ...
# 1478  {'heading': 'Features', 'top': [{'value': 'Pow...    Diesel
# 1479  {'heading': 'Features', 'top': [{'value': 'Pow...    Diesel
# 1480  {'heading': 'Features', 'top': [{'value': 'Pow...    Diesel
# 1481  {'heading': 'Features', 'top': [{'value': 'Pow...    Diesel
# 1482  {'heading': 'Features', 'top': [{'value': 'Pow...    Diesel
#
#      Transmission type  Body type Kilometers driven  \
# 0            Automatic  Hatchback            20,000
# 1               Manual  Hatchback            85,582
# 2               Manual        SUV            10,000
# 3               Manual  Hatchback            50,750
# 4            Automatic        SUV            10,000
# ...                ...        ...               ...
# 1478            Manual        SUV            60,000
# 1479         Automatic      Sedan            50,000
# 1480         Automatic      Sedan          1,20,000
# 1481         Automatic        SUV            50,000
# 1482            Manual        MUV          1,00,000
#
#       Number of previous owners Ownership details  \
# 0                             1         1st Owner
# 1                             2         2nd Owner
# 2                             1         1st Owner
# 3                             1         1st Owner
# 4                             1         1st Owner
# ...                         ...               ...
# 1478                          1         1st Owner
# 1479                          1         1st Owner
# 1480                          3         3rd Owner
# 1481                          2         2nd Owner
# 1482                          1         1st Owner
#
#      Original Equipment Manufacturer        Car model  \
# 0                         Volkswagen  Volkswagen Polo
# 1                            Hyundai      Hyundai EON
# 2                            Hyundai    Hyundai Venue
# 3                             Maruti    Maruti Baleno
# 4                           Mahindra    Mahindra Thar
# ...                              ...              ...
# 1478                        Mahindra  Mahindra XUV500
# 1479                          Jaguar        Jaguar XF
# 1480                             BMW     BMW 5 Series
# 1481                            Tata       Tata Nexon
# 1482                          Toyota    Toyota Innova
#
#       Year of car manufacture   Central variant ID  \
# 0                        2022                 7746
# 1                        2014                 1502
# 2                        2023                 9153
# 3                        2017                 3970
# 4                        2022                 8074
# ...                       ...                  ...
# 1478                     2013                 3823
# 1479                     2014                 5007
# 1480                     2018                  250
# 1481                     2019                 6500
# 1482                     2015                 2294
#
#                     Variant name Price of the used car Actual price  \
# 0       1.0 TSI Highline Plus AT          ₹ 10.44 Lakh
# 1                       Era Plus           ₹ 2.60 Lakh
# 2                         S BSVI           ₹ 9.55 Lakh
# 3                      1.2 Alpha           ₹ 6.71 Lakh
# 4      LX 4-Str Hard Top AT BSVI             ₹ 19 Lakh
# ...                          ...                   ...          ...
# 1478                      W8 2WD              ₹ 7 Lakh
# 1479  3.0 Litre S Premium Luxury             ₹ 20 Lakh
# 1480            520d Luxury Line             ₹ 35 Lakh
# 1481            1.5 Revotorq XMA           ₹ 8.50 Lakh
# 1482      2.5 ZX Diesel 7 Seater             ₹ 15 Lakh
#
#      Price saving  Fixed price details   Location
# 0                                 None  Hyderabad
# 1                                 None  Hyderabad
# 2                                 None  Hyderabad
# 3                                 None  Hyderabad
# 4                                 None  Hyderabad
# ...            ...                 ...        ...
# 1478                              None  Hyderabad
# 1479                              None  Hyderabad
# 1480                              None  Hyderabad
# 1481                              None  Hyderabad
# 1482                              None  Hyderabad
#
# [1483 rows x 18 columns]

# %% [markdown]
# **concat**

# %%
#import pandas as pd

# Assuming 'data' and 'd1' are your DataFrames

# Concatenate vertically (along rows)
#concatenated_table = pd.concat([data, d1], ignore_index=True)

# concatenated_table now contains both data from 'data' and 'd1' stacked vertically.

# %%
d2=pd.read_excel("/content/delhi_cars.xlsx")#read the file

# %%
d2.shape #rows,columns
# Out:
# (1485, 5)

# %%
import ast
import pandas as pd

# Assuming 'data' is your DataFrame
collection_name=[]
for i in d2['new_car_detail'].values:
  if i == i:
    collection_name.append(ast.literal_eval(i)['ft'])

d2["fuel type"]=collection_name  #create a new column

collection_name = []
for i in d2['new_car_detail'].values:
    if i == i:
        collection_name.append(ast.literal_eval(i).get('transmission'))

d2["Transmission type"] = collection_name

collection_name = []
for i in d2['new_car_detail'].values:
    if i == i:
        collection_name.append(ast.literal_eval(i).get('bt'))

d2["Body type"] = collection_name

collection_name = []
for i in d2['new_car_detail'].values:
    if i == i:
        collection_name.append(ast.literal_eval(i).get('km'))

d2["Kilometers driven"] = collection_name

collection_name = []
for i in d2['new_car_detail'].values:
    if i == i:
        collection_name.append(ast.literal_eval(i).get('ownerNo'))

d2["Number of previous owners"] = collection_name

collection_name = []
for i in d2['new_car_detail'].values:
    if i == i:
        collection_name.append(ast.literal_eval(i).get('owner'))

d2["Ownership details"] = collection_name

collection_name = []
for i in d2['new_car_detail'].values:
    if i == i:
        collection_name.append(ast.literal_eval(i).get('oem'))

d2["Original Equipment Manufacturer"] = collection_name


collection_name = []
for i in d2['new_car_detail'].values:
    if i == i:
        collection_name.append(ast.literal_eval(i).get('model'))

d2["Car model"] = collection_name

collection_name = []
for i in d2['new_car_detail'].values:
    if i == i:
        collection_name.append(ast.literal_eval(i).get('modelYear'))

d2["Year of car manufacture"] = collection_name

collection_name = []
for i in d2['new_car_detail'].values:
    if i == i:
        collection_name.append(ast.literal_eval(i).get('centralVariantId'))

d2[" Central variant ID"] = collection_name

collection_name = []
for i in d2['new_car_detail'].values:
    if i == i:
        collection_name.append(ast.literal_eval(i).get('variantName'))

d2["Variant name"] = collection_name

collection_name = []
for i in d2['new_car_detail'].values:
    if i == i:
        collection_name.append(ast.literal_eval(i).get('price'))

d2["Price of the used car"] = collection_name


collection_name = []
for i in d2['new_car_detail'].values:
    if i == i:
        collection_name.append(ast.literal_eval(i).get('priceActual'))

d2["Actual price"] = collection_name

collection_name = []
for i in d2['new_car_detail'].values:
    if i == i:
        collection_name.append(ast.literal_eval(i).get('priceSaving'))

d2["Price saving "] = collection_name

collection_name = []
for i in d2['new_car_detail'].values:
    if i == i:
        collection_name.append(ast.literal_eval(i).get('priceFixedText'))

d2["Fixed price details"] = collection_name

# %%
d2 = d2.drop(columns = ['new_car_specs'])# 'new_car_overview','new_car_feature',

# %%
d2 = d2.drop(columns = ['car_links'])

# %%
d2 = d2.drop(columns = ['new_car_detail'])

# %%
d2['Location'] = 'Delhi'

# %%
d2
# Out:
#                                        new_car_overview  \
# 0     {'heading': 'Car overview', 'top': [{'key': 'R...
# 1     {'heading': 'Car overview', 'top': [{'key': 'R...
# 2     {'heading': 'Car overview', 'top': [{'key': 'R...
# 3     {'heading': 'Car overview', 'top': [{'key': 'R...
# 4     {'heading': 'Car overview', 'top': [{'key': 'R...
# ...                                                 ...
# 1480  {'heading': 'Car overview', 'top': [{'key': 'R...
# 1481  {'heading': 'Car overview', 'top': [{'key': 'R...
# 1482  {'heading': 'Car overview', 'top': [{'key': 'R...
# 1483  {'heading': 'Car overview', 'top': [{'key': 'R...
# 1484  {'heading': 'Car overview', 'top': [{'key': 'I...
#
#                                         new_car_feature fuel type  \
# 0     {'heading': 'Features', 'top': [{'value': 'Pow...    Diesel
# 1     {'heading': 'Features', 'top': [{'value': 'Pow...    Petrol
# 2     {'heading': 'Features', 'top': [{'value': 'Pow...    Petrol
# 3     {'heading': 'Features', 'top': [{'value': 'Pow...    Petrol
# 4     {'heading': 'Features', 'top': [{'value': 'Pow...    Petrol
# ...                                                 ...       ...
# 1480  {'heading': 'Features', 'top': [{'value': 'Pow...    Petrol
# 1481  {'heading': 'Features', 'top': [{'value': 'Pow...    Petrol
# 1482  {'heading': 'Features', 'top': [{'value': 'Pow...    Petrol
# 1483  {'heading': 'Features', 'top': [{'value': 'Pow...    Diesel
# 1484  {'heading': 'Features', 'top': [{'value': 'Pow...    Diesel
#
#      Transmission type  Body type Kilometers driven  \
# 0            Automatic        SUV            10,000
# 1               Manual        SUV            57,437
# 2            Automatic        SUV             8,000
# 3               Manual  Hatchback            28,151
# 4               Manual        SUV            60,000
# ...                ...        ...               ...
# 1480         Automatic      Sedan            60,000
# 1481            Manual        SUV            20,000
# 1482            Manual      Sedan            60,000
# 1483            Manual        SUV            38,000
# 1484         Automatic        SUV             7,000
#
#       Number of previous owners Ownership details  \
# 0                             1         1st Owner
# 1                             2         2nd Owner
# 2                             1         1st Owner
# 3                             2         2nd Owner
# 4                             1         1st Owner
# ...                         ...               ...
# 1480                          1         1st Owner
# 1481                          1         1st Owner
# 1482                          1         1st Owner
# 1483                          1         1st Owner
# 1484                          0         0th Owner
#
#      Original Equipment Manufacturer          Car model  \
# 0                                Kia         Kia Seltos
# 1                            Hyundai      Hyundai Creta
# 2                      Mercedes-Benz  Mercedes-Benz GLC
# 3                             Maruti       Maruti Swift
# 4                            Hyundai      Hyundai Creta
# ...                              ...                ...
# 1480                           Honda         Honda City
# 1481                             Kia          Kia Sonet
# 1482                         Hyundai      Hyundai Verna
# 1483                         Hyundai      Hyundai Creta
# 1484                              MG         MG Gloster
#
#       Year of car manufacture   Central variant ID          Variant name  \
# 0                        2022                 7121    GTX Plus Diesel AT
# 1                        2016                 1449            1.6 VTVT S
# 2                        2020                 6837                   200
# 3                        2018                10403                   VXI
# 4                        2017                 5362       1.6 VTVT E Plus
# ...                       ...                  ...                   ...
# 1480                     2019                 5627          i-VTEC CVT V
# 1481                     2021                 8000         HTK Plus BSVI
# 1482                     2011                 1832           1.6 SX VTVT
# 1483                     2019                 6440  1.6 SX Option Diesel
# 1484                     2023                 9298       Savvy 6 Str 4x4
#
#      Price of the used car Actual price Price saving  Fixed price details  \
# 0                ₹ 19 Lakh                                           None
# 1              ₹ 7.62 Lakh                                           None
# 2                ₹ 56 Lakh                                           None
# 3              ₹ 5.23 Lakh                                           None
# 4              ₹ 7.65 Lakh                                           None
# ...                    ...          ...           ...                 ...
# 1480              ₹ 9 Lakh                                           None
# 1481           ₹ 9.50 Lakh                                           None
# 1482           ₹ 4.18 Lakh                                           None
# 1483          ₹ 11.95 Lakh                                           None
# 1484          ₹ 46.40 Lakh                                           None
#
#      Location
# 0       Delhi
# 1       Delhi
# 2       Delhi
# 3       Delhi
# 4       Delhi
# ...       ...
# 1480    Delhi
# 1481    Delhi
# 1482    Delhi
# 1483    Delhi
# 1484    Delhi
#
# [1485 rows x 18 columns]

# %%
d3=pd.read_excel("/content/jaipur_cars.xlsx")#read the file
d3.shape #rows,columns
# Out:
# (1120, 5)

# %%
import ast
import pandas as pd

# Assuming 'data' is your DataFrame
collection_name=[]
for i in d3['new_car_detail'].values:
  if i == i:
    collection_name.append(ast.literal_eval(i)['ft'])

d3["fuel type"]=collection_name  #create a new column

collection_name = []
for i in d3['new_car_detail'].values:
    if i == i:
        collection_name.append(ast.literal_eval(i).get('transmission'))

d3["Transmission type"] = collection_name

collection_name = []
for i in d3['new_car_detail'].values:
    if i == i:
        collection_name.append(ast.literal_eval(i).get('bt'))

d3["Body type"] = collection_name

collection_name = []
for i in d3['new_car_detail'].values:
    if i == i:
        collection_name.append(ast.literal_eval(i).get('km'))

d3["Kilometers driven"] = collection_name

collection_name = []
for i in d3['new_car_detail'].values:
    if i == i:
        collection_name.append(ast.literal_eval(i).get('ownerNo'))

d3["Number of previous owners"] = collection_name

collection_name = []
for i in d3['new_car_detail'].values:
    if i == i:
        collection_name.append(ast.literal_eval(i).get('owner'))

d3["Ownership details"] = collection_name

collection_name = []
for i in d3['new_car_detail'].values:
    if i == i:
        collection_name.append(ast.literal_eval(i).get('oem'))

d3["Original Equipment Manufacturer"] = collection_name


collection_name = []
for i in d3['new_car_detail'].values:
    if i == i:
        collection_name.append(ast.literal_eval(i).get('model'))

d3["Car model"] = collection_name

collection_name = []
for i in d3['new_car_detail'].values:
    if i == i:
        collection_name.append(ast.literal_eval(i).get('modelYear'))

d3["Year of car manufacture"] = collection_name

collection_name = []
for i in d3['new_car_detail'].values:
    if i == i:
        collection_name.append(ast.literal_eval(i).get('centralVariantId'))

d3[" Central variant ID"] = collection_name

collection_name = []
for i in d3['new_car_detail'].values:
    if i == i:
        collection_name.append(ast.literal_eval(i).get('variantName'))

d3["Variant name"] = collection_name

collection_name = []
for i in d3['new_car_detail'].values:
    if i == i:
        collection_name.append(ast.literal_eval(i).get('price'))

d3["Price of the used car"] = collection_name


collection_name = []
for i in d3['new_car_detail'].values:
    if i == i:
        collection_name.append(ast.literal_eval(i).get('priceActual'))

d3["Actual price"] = collection_name

collection_name = []
for i in d3['new_car_detail'].values:
    if i == i:
        collection_name.append(ast.literal_eval(i).get('priceSaving'))

d3["Price saving "] = collection_name

collection_name = []
for i in d3['new_car_detail'].values:
    if i == i:
        collection_name.append(ast.literal_eval(i).get('priceFixedText'))

d3["Fixed price details"] = collection_name

# %%
d3 = d3.drop(columns = ['new_car_specs'])# 'new_car_overview','new_car_feature',
d3 = d3.drop(columns = ['car_links'])
d3 = d3.drop(columns = ['new_car_detail'])
d3['Location'] = 'Jaipur'

# %%
d3
# Out:
#                                        new_car_overview  \
# 0     {'heading': 'Car overview', 'top': [{'key': 'R...
# 1     {'heading': 'Car overview', 'top': [{'key': 'R...
# 2     {'heading': 'Car overview', 'top': [{'key': 'R...
# 3     {'heading': 'Car overview', 'top': [{'key': 'R...
# 4     {'heading': 'Car overview', 'top': [{'key': 'R...
# ...                                                 ...
# 1115  {'heading': 'Car overview', 'top': [{'key': 'R...
# 1116  {'heading': 'Car overview', 'top': [{'key': 'R...
# 1117  {'heading': 'Car overview', 'top': [{'key': 'R...
# 1118  {'heading': 'Car overview', 'top': [{'key': 'R...
# 1119  {'heading': 'Car overview', 'top': [{'key': 'R...
#
#                                         new_car_feature fuel type  \
# 0     {'heading': 'Features', 'top': [{'value': 'Pow...    Diesel
# 1     {'heading': 'Features', 'top': [{'value': 'Pow...    Petrol
# 2     {'heading': 'Features', 'top': [{'value': 'Pow...    Petrol
# 3     {'heading': 'Features', 'top': [{'value': 'Pow...    Petrol
# 4     {'heading': 'Features', 'top': [{'value': 'Pow...    Petrol
# ...                                                 ...       ...
# 1115  {'heading': 'Features', 'top': [{'value': 'Pow...    Petrol
# 1116  {'heading': 'Features', 'top': [{'value': 'Low...    Petrol
# 1117  {'heading': 'Features', 'top': [{'value': 'Pow...    Petrol
# 1118  {'heading': 'Features', 'top': [{'value': 'Low...    Petrol
# 1119  {'heading': 'Features', 'top': [{'value': 'Pow...    Petrol
#
#      Transmission type  Body type Kilometers driven  \
# 0               Manual  Hatchback          1,20,000
# 1               Manual  Hatchback            66,951
# 2            Automatic  Hatchback            80,000
# 3               Manual  Hatchback            44,392
# 4            Automatic  Hatchback            40,000
# ...                ...        ...               ...
# 1115            Manual  Hatchback          1,20,000
# 1116            Manual  Hatchback            70,000
# 1117            Manual        SUV            20,000
# 1118            Manual  Hatchback            40,000
# 1119            Manual  Hatchback            80,000
#
#       Number of previous owners Ownership details  \
# 0                             2         2nd Owner
# 1                             1         1st Owner
# 2                             2         2nd Owner
# 3                             1         1st Owner
# 4                             1         1st Owner
# ...                         ...               ...
# 1115                          1         1st Owner
# 1116                          1         1st Owner
# 1117                          1         1st Owner
# 1118                          1         1st Owner
# 1119                          1         1st Owner
#
#      Original Equipment Manufacturer          Car model  \
# 0                            Hyundai        Hyundai i20
# 1                             Maruti       Maruti Swift
# 2                             Maruti     Maruti Celerio
# 3                            Hyundai  Hyundai Grand i10
# 4                             Maruti     Maruti Wagon R
# ...                              ...                ...
# 1115                       Chevrolet     Chevrolet Beat
# 1116                          Maruti        Maruti Alto
# 1117                         Renault      Renault Kiger
# 1118                          Maruti        Maruti Alto
# 1119                          Maruti      Maruti Baleno
#
#       Year of car manufacture   Central variant ID          Variant name  \
# 0                        2015                 1487         Asta 1.4 CRDi
# 1                        2012                10403                   VXI
# 2                        2016                 3982                VXI AT
# 3                        2017                 5602  1.2 Kappa Magna BSIV
# 4                        2016                 4319               AMT VXI
# ...                       ...                  ...                   ...
# 1115                     2011                  438                    LT
# 1116                     2007                 3917                   STD
# 1117                     2022                 8350                   RXZ
# 1118                     2009                 3904                   Std
# 1119                     2018                 3962             1.2 Delta
#
#      Price of the used car Actual price Price saving  Fixed price details  \
# 0              ₹ 5.10 Lakh                                           None
# 1              ₹ 3.81 Lakh                                           None
# 2              ₹ 3.20 Lakh                                           None
# 3              ₹ 4.20 Lakh                                           None
# 4              ₹ 3.50 Lakh                                           None
# ...                    ...          ...           ...                 ...
# 1115           ₹ 1.08 Lakh                                           None
# 1116           ₹ 1.05 Lakh                                           None
# 1117           ₹ 8.50 Lakh                                           None
# 1118              ₹ 1 Lakh                                           None
# 1119              ₹ 5 Lakh                                           None
#
#      Location
# 0      Jaipur
# 1      Jaipur
# 2      Jaipur
# 3      Jaipur
# 4      Jaipur
# ...       ...
# 1115   Jaipur
# 1116   Jaipur
# 1117   Jaipur
# 1118   Jaipur
# 1119   Jaipur
#
# [1120 rows x 18 columns]

# %%
d4=pd.read_excel("/content/kolkata_cars.xlsx")#read the file
d4.shape #rows,columns
# Out:
# (1381, 5)

# %%
import ast
import pandas as pd

# Assuming 'data' is your DataFrame
collection_name=[]
for i in d4['new_car_detail'].values:
  if i == i:
    collection_name.append(ast.literal_eval(i)['ft'])

d4["fuel type"]=collection_name  #create a new column

collection_name = []
for i in d4['new_car_detail'].values:
    if i == i:
        collection_name.append(ast.literal_eval(i).get('transmission'))

d4["Transmission type"] = collection_name

collection_name = []
for i in d4['new_car_detail'].values:
    if i == i:
        collection_name.append(ast.literal_eval(i).get('bt'))

d4["Body type"] = collection_name

collection_name = []
for i in d4['new_car_detail'].values:
    if i == i:
        collection_name.append(ast.literal_eval(i).get('km'))

d4["Kilometers driven"] = collection_name

collection_name = []
for i in d4['new_car_detail'].values:
    if i == i:
        collection_name.append(ast.literal_eval(i).get('ownerNo'))

d4["Number of previous owners"] = collection_name

collection_name = []
for i in d4['new_car_detail'].values:
    if i == i:
        collection_name.append(ast.literal_eval(i).get('owner'))

d4["Ownership details"] = collection_name

collection_name = []
for i in d4['new_car_detail'].values:
    if i == i:
        collection_name.append(ast.literal_eval(i).get('oem'))

d4["Original Equipment Manufacturer"] = collection_name


collection_name = []
for i in d4['new_car_detail'].values:
    if i == i:
        collection_name.append(ast.literal_eval(i).get('model'))

d4["Car model"] = collection_name

collection_name = []
for i in d4['new_car_detail'].values:
    if i == i:
        collection_name.append(ast.literal_eval(i).get('modelYear'))

d4["Year of car manufacture"] = collection_name

collection_name = []
for i in d4['new_car_detail'].values:
    if i == i:
        collection_name.append(ast.literal_eval(i).get('centralVariantId'))

d4[" Central variant ID"] = collection_name

collection_name = []
for i in d4['new_car_detail'].values:
    if i == i:
        collection_name.append(ast.literal_eval(i).get('variantName'))

d4["Variant name"] = collection_name

collection_name = []
for i in d4['new_car_detail'].values:
    if i == i:
        collection_name.append(ast.literal_eval(i).get('price'))

d4["Price of the used car"] = collection_name


collection_name = []
for i in d4['new_car_detail'].values:
    if i == i:
        collection_name.append(ast.literal_eval(i).get('priceActual'))

d4["Actual price"] = collection_name

collection_name = []
for i in d4['new_car_detail'].values:
    if i == i:
        collection_name.append(ast.literal_eval(i).get('priceSaving'))

d4["Price saving "] = collection_name

collection_name = []
for i in d4['new_car_detail'].values:
    if i == i:
        collection_name.append(ast.literal_eval(i).get('priceFixedText'))

d4["Fixed price details"] = collection_name

# %%
d4 = d4.drop(columns = ['new_car_specs'])#'new_car_overview','new_car_feature'
d4 = d4.drop(columns = ['car_links'])
d4 = d4.drop(columns = ['new_car_detail'])
d4['Location'] = 'Kolkata'

# %%
d4
# Out:
#                                        new_car_overview  \
# 0     {'heading': 'Car overview', 'top': [{'key': 'R...
# 1     {'heading': 'Car overview', 'top': [{'key': 'R...
# 2     {'heading': 'Car overview', 'top': [{'key': 'R...
# 3     {'heading': 'Car overview', 'top': [{'key': 'R...
# 4     {'heading': 'Car overview', 'top': [{'key': 'R...
# ...                                                 ...
# 1376  {'heading': 'Car overview', 'top': [{'key': 'R...
# 1377  {'heading': 'Car overview', 'top': [{'key': 'R...
# 1378  {'heading': 'Car overview', 'top': [{'key': 'R...
# 1379  {'heading': 'Car overview', 'top': [{'key': 'R...
# 1380  {'heading': 'Car overview', 'top': [{'key': 'R...
#
#                                         new_car_feature fuel type  \
# 0     {'heading': 'Features', 'top': [{'value': 'Pow...    Petrol
# 1     {'heading': 'Features', 'top': [{'value': 'Pow...    Petrol
# 2     {'heading': 'Features', 'top': [{'value': 'Pow...    Petrol
# 3     {'heading': 'Features', 'top': [{'value': 'Pow...    Petrol
# 4     {'heading': 'Features', 'top': [{'value': 'Pow...    Diesel
# ...                                                 ...       ...
# 1376  {'heading': 'Features', 'top': [{'value': 'Pow...    Petrol
# 1377  {'heading': 'Features', 'top': [{'value': 'Pow...    Petrol
# 1378  {'heading': 'Features', 'top': [{'value': 'Pow...    Petrol
# 1379  {'heading': 'Features', 'top': [{'value': 'Pow...    Petrol
# 1380  {'heading': 'Features', 'top': [{'value': 'Pow...    Diesel
#
#      Transmission type  Body type Kilometers driven  \
# 0            Automatic      Sedan            70,000
# 1               Manual  Hatchback            23,981
# 2            Automatic        SUV             7,100
# 3               Manual  Hatchback            71,574
# 4            Automatic        SUV            50,000
# ...                ...        ...               ...
# 1376            Manual  Hatchback            10,000
# 1377            Manual  Hatchback          1,20,000
# 1378         Automatic      Sedan            50,000
# 1379            Manual  Hatchback            40,000
# 1380            Manual        SUV          1,20,000
#
#       Number of previous owners Ownership details  \
# 0                             3         3rd Owner
# 1                             1         1st Owner
# 2                             1         1st Owner
# 3                             2         2nd Owner
# 4                             2         2nd Owner
# ...                         ...               ...
# 1376                          1         1st Owner
# 1377                          1         1st Owner
# 1378                          3         3rd Owner
# 1379                          1         1st Owner
# 1380                          2         2nd Owner
#
#      Original Equipment Manufacturer              Car model  \
# 0                             Toyota           Toyota Camry
# 1                             Datsun          Datsun RediGO
# 2                            Renault          Renault Kiger
# 3                            Hyundai            Hyundai i20
# 4                               Audi                Audi Q3
# ...                              ...                    ...
# 1376                          Maruti         Maruti Celerio
# 1377                          Maruti        Maruti Alto 800
# 1378                   Mercedes-Benz  Mercedes-Benz C-Class
# 1379                          Maruti            Maruti Ritz
# 1380                         Renault         Renault Duster
#
#       Year of car manufacture   Central variant ID            Variant name  \
# 0                        2014                 2123                  Hybrid
# 1                        2017                 5236                T Option
# 2                        2021                 8352                 RXT AMT
# 3                        2011                 1642              1.2 Sportz
# 4                        2014                   99  35 TDI Quattro Premium
# ...                       ...                  ...                     ...
# 1376                     2022                 8682                ZXI BSVI
# 1377                     2014                 3943                     LXI
# 1378                     2011                 4672      C 200 CGI Elegance
# 1379                     2012                 4144                     ZXi
# 1380                     2017                 5048    110PS Diesel RxZ AWD
#
#      Price of the used car Actual price Price saving  Fixed price details  \
# 0              ₹ 9.75 Lakh                                           None
# 1              ₹ 2.66 Lakh                                           None
# 2              ₹ 5.95 Lakh                                           None
# 3              ₹ 2.23 Lakh                                           None
# 4                ₹ 12 Lakh                                           None
# ...                    ...          ...           ...                 ...
# 1376           ₹ 5.10 Lakh                                           None
# 1377           ₹ 1.80 Lakh                                           None
# 1378           ₹ 5.50 Lakh                                           None
# 1379           ₹ 1.40 Lakh                                           None
# 1380              ₹ 5 Lakh                                           None
#
#      Location
# 0     Kolkata
# 1     Kolkata
# 2     Kolkata
# 3     Kolkata
# 4     Kolkata
# ...       ...
# 1376  Kolkata
# 1377  Kolkata
# 1378  Kolkata
# 1379  Kolkata
# 1380  Kolkata
#
# [1381 rows x 18 columns]

# %%
d5=pd.read_excel("/content/bangalore_cars.xlsx")#read the file
d5.shape #rows,columns
# Out:
# (1481, 5)

# %%
import ast
import pandas as pd

# Assuming 'data' is your DataFrame
collection_name=[]
for i in d5['new_car_detail'].values:
  if i == i:
    collection_name.append(ast.literal_eval(i)['ft'])

d5["fuel type"]=collection_name  #create a new column

collection_name = []
for i in d5['new_car_detail'].values:
    if i == i:
        collection_name.append(ast.literal_eval(i).get('transmission'))

d5["Transmission type"] = collection_name

collection_name = []
for i in d5['new_car_detail'].values:
    if i == i:
        collection_name.append(ast.literal_eval(i).get('bt'))

d5["Body type"] = collection_name

collection_name = []
for i in d5['new_car_detail'].values:
    if i == i:
        collection_name.append(ast.literal_eval(i).get('km'))

d5["Kilometers driven"] = collection_name

collection_name = []
for i in d5['new_car_detail'].values:
    if i == i:
        collection_name.append(ast.literal_eval(i).get('ownerNo'))

d5["Number of previous owners"] = collection_name

collection_name = []
for i in d5['new_car_detail'].values:
    if i == i:
        collection_name.append(ast.literal_eval(i).get('owner'))

d5["Ownership details"] = collection_name

collection_name = []
for i in d5['new_car_detail'].values:
    if i == i:
        collection_name.append(ast.literal_eval(i).get('oem'))

d5["Original Equipment Manufacturer"] = collection_name


collection_name = []
for i in d5['new_car_detail'].values:
    if i == i:
        collection_name.append(ast.literal_eval(i).get('model'))

d5["Car model"] = collection_name

collection_name = []
for i in d5['new_car_detail'].values:
    if i == i:
        collection_name.append(ast.literal_eval(i).get('modelYear'))

d5["Year of car manufacture"] = collection_name

collection_name = []
for i in d5['new_car_detail'].values:
    if i == i:
        collection_name.append(ast.literal_eval(i).get('centralVariantId'))

d5[" Central variant ID"] = collection_name

collection_name = []
for i in d5['new_car_detail'].values:
    if i == i:
        collection_name.append(ast.literal_eval(i).get('variantName'))

d5["Variant name"] = collection_name

collection_name = []
for i in d5['new_car_detail'].values:
    if i == i:
        collection_name.append(ast.literal_eval(i).get('price'))

d5["Price of the used car"] = collection_name


collection_name = []
for i in d5['new_car_detail'].values:
    if i == i:
        collection_name.append(ast.literal_eval(i).get('priceActual'))

d5["Actual price"] = collection_name

collection_name = []
for i in d5['new_car_detail'].values:
    if i == i:
        collection_name.append(ast.literal_eval(i).get('priceSaving'))

d5["Price saving "] = collection_name

collection_name = []
for i in d5['new_car_detail'].values:
    if i == i:
        collection_name.append(ast.literal_eval(i).get('priceFixedText'))

d5["Fixed price details"] = collection_name

# %%
d5 = d5.drop(columns = ['new_car_specs'])#'new_car_overview','new_car_feature',
d5 = d5.drop(columns = ['car_links'])
d5 = d5.drop(columns = ['new_car_detail'])
d5['Location'] = 'Bangalore'

# %%
d5
# Out:
#                                        new_car_overview  \
# 0     {'heading': 'Car overview', 'top': [{'key': 'R...
# 1     {'heading': 'Car overview', 'top': [{'key': 'R...
# 2     {'heading': 'Car overview', 'top': [{'key': 'R...
# 3     {'heading': 'Car overview', 'top': [{'key': 'R...
# 4     {'heading': 'Car overview', 'top': [{'key': 'R...
# ...                                                 ...
# 1476  {'heading': 'Car overview', 'top': [{'key': 'R...
# 1477  {'heading': 'Car overview', 'top': [{'key': 'R...
# 1478  {'heading': 'Car overview', 'top': [{'key': 'R...
# 1479  {'heading': 'Car overview', 'top': [{'key': 'R...
# 1480  {'heading': 'Car overview', 'top': [{'key': 'R...
#
#                                         new_car_feature fuel type  \
# 0     {'heading': 'Features', 'top': [{'value': 'Pow...    Petrol
# 1     {'heading': 'Features', 'top': [{'value': 'Pow...    Petrol
# 2     {'heading': 'Features', 'top': [{'value': 'Pow...    Petrol
# 3     {'heading': 'Features', 'top': [{'value': 'Pow...    Petrol
# 4     {'heading': 'Features', 'top': [{'value': 'Pow...    Diesel
# ...                                                 ...       ...
# 1476  {'heading': 'Features', 'top': [{'value': 'Pow...    Diesel
# 1477  {'heading': 'Features', 'top': [{'value': 'Pow...    Petrol
# 1478  {'heading': 'Features', 'top': [{'value': 'Pow...    Petrol
# 1479  {'heading': 'Features', 'top': [{'value': 'Pow...    Diesel
# 1480  {'heading': 'Features', 'top': [{'value': 'Pow...    Petrol
#
#      Transmission type  Body type Kilometers driven  \
# 0               Manual  Hatchback          1,20,000
# 1               Manual        SUV            32,706
# 2               Manual  Hatchback            11,949
# 3               Manual      Sedan            17,794
# 4               Manual        SUV            60,000
# ...                ...        ...               ...
# 1476            Manual        SUV          1,56,039
# 1477            Manual      Sedan            56,000
# 1478            Manual  Hatchback            42,000
# 1479            Manual  Hatchback            93,003
# 1480         Automatic  Hatchback            36,000
#
#       Number of previous owners Ownership details  \
# 0                             3         3rd Owner
# 1                             2         2nd Owner
# 2                             1         1st Owner
# 3                             1         1st Owner
# 4                             1         1st Owner
# ...                         ...               ...
# 1476                          2         2nd Owner
# 1477                          2         2nd Owner
# 1478                          2         2nd Owner
# 1479                          1         1st Owner
# 1480                          2         2nd Owner
#
#      Original Equipment Manufacturer           Car model  \
# 0                             Maruti      Maruti Celerio
# 1                               Ford       Ford Ecosport
# 2                               Tata          Tata Tiago
# 3                            Hyundai       Hyundai Xcent
# 4                             Maruti  Maruti SX4 S Cross
# ...                              ...                 ...
# 1476                          Toyota     Toyota Fortuner
# 1477                          Maruti          Maruti SX4
# 1478                           Honda          Honda Brio
# 1479                         Hyundai         Hyundai i20
# 1480                         Hyundai   Hyundai Grand i10
#
#       Year of car manufacture   Central variant ID              Variant name  \
# 0                        2015                 3979                       VXI
# 1                        2018                 6087  1.5 Petrol Titanium BSIV
# 2                        2018                 2983           1.2 Revotron XZ
# 3                        2014                 1867        1.2 Kappa S Option
# 4                        2015                 4277             DDiS 200 Zeta
# ...                       ...                  ...                       ...
# 1476                     2012                 2253                    4x4 MT
# 1477                     2008                 4257                 Zxi BSIII
# 1478                     2014                 1188                      S MT
# 1479                     2018                 5695        1.4 Asta Dual Tone
# 1480                     2017                 1523            Asta Option AT
#
#      Price of the used car Actual price Price saving  Fixed price details  \
# 0                 ₹ 4 Lakh                                           None
# 1              ₹ 8.11 Lakh                                           None
# 2              ₹ 5.85 Lakh                                           None
# 3              ₹ 4.62 Lakh                                           None
# 4              ₹ 7.90 Lakh                                           None
# ...                    ...          ...           ...                 ...
# 1476          ₹ 16.49 Lakh                                           None
# 1477           ₹ 3.30 Lakh                                           None
# 1478           ₹ 4.25 Lakh                                           None
# 1479           ₹ 7.50 Lakh                                           None
# 1480           ₹ 6.75 Lakh                                           None
#
#        Location
# 0     Bangalore
# 1     Bangalore
# 2     Bangalore
# 3     Bangalore
# 4     Bangalore
# ...         ...
# 1476  Bangalore
# 1477  Bangalore
# 1478  Bangalore
# 1479  Bangalore
# 1480  Bangalore
#
# [1481 rows x 18 columns]

# %%
import pandas as pd

# Assuming 'data' and 'd1' are your DataFrames

# Concatenate vertically (along rows)
cardekho = pd.concat([data, d1,d2,d3,d4,d5], ignore_index=True)

# concatenated_table now contains both data from 'data' and 'd1' stacked vertically.

# %%
cardekho
# Out:
#                                        new_car_overview  \
# 0     {'heading': 'Car overview', 'top': [{'key': 'R...
# 1     {'heading': 'Car overview', 'top': [{'key': 'R...
# 2     {'heading': 'Car overview', 'top': [{'key': 'R...
# 3     {'heading': 'Car overview', 'top': [{'key': 'R...
# 4     {'heading': 'Car overview', 'top': [{'key': 'R...
# ...                                                 ...
# 8364  {'heading': 'Car overview', 'top': [{'key': 'R...
# 8365  {'heading': 'Car overview', 'top': [{'key': 'R...
# 8366  {'heading': 'Car overview', 'top': [{'key': 'R...
# 8367  {'heading': 'Car overview', 'top': [{'key': 'R...
# 8368  {'heading': 'Car overview', 'top': [{'key': 'R...
#
#                                         new_car_feature fuel type  Body type  \
# 0     {'heading': 'Features', 'top': [{'value': 'Pow...    Petrol        SUV
# 1     {'heading': 'Features', 'top': [{'value': 'Low...    Petrol   Minivans
# 2     {'heading': 'Features', 'top': [{'value': 'Pow...    Petrol        SUV
# 3     {'heading': 'Features', 'top': [{'value': 'Pow...    Petrol  Hatchback
# 4     {'heading': 'Features', 'top': [{'value': 'Pow...    Petrol  Hatchback
# ...                                                 ...       ...        ...
# 8364  {'heading': 'Features', 'top': [{'value': 'Pow...    Diesel        SUV
# 8365  {'heading': 'Features', 'top': [{'value': 'Pow...    Petrol      Sedan
# 8366  {'heading': 'Features', 'top': [{'value': 'Pow...    Petrol  Hatchback
# 8367  {'heading': 'Features', 'top': [{'value': 'Pow...    Diesel  Hatchback
# 8368  {'heading': 'Features', 'top': [{'value': 'Pow...    Petrol  Hatchback
#
#      Kilometers driven Transmission type  Number of previous owners  \
# 0               20,000         Automatic                          1
# 1               20,687            Manual                          1
# 2               30,000            Manual                          1
# 3               59,247            Manual                          1
# 4               50,000            Manual                          1
# ...                ...               ...                        ...
# 8364          1,56,039            Manual                          2
# 8365            56,000            Manual                          2
# 8366            42,000            Manual                          2
# 8367            93,003            Manual                          1
# 8368            36,000         Automatic                          2
#
#      Ownership details Original Equipment Manufacturer          Car model  \
# 0            1st Owner                             Kia          Kia Sonet
# 1            1st Owner                          Maruti        Maruti Eeco
# 2            1st Owner                          Nissan     Nissan Magnite
# 3            1st Owner                         Hyundai        Hyundai i10
# 4            1st Owner                           Honda         Honda Jazz
# ...                ...                             ...                ...
# 8364         2nd Owner                          Toyota    Toyota Fortuner
# 8365         2nd Owner                          Maruti         Maruti SX4
# 8366         2nd Owner                           Honda         Honda Brio
# 8367         1st Owner                         Hyundai        Hyundai i20
# 8368         2nd Owner                         Hyundai  Hyundai Grand i10
#
#       Year of car manufacture  Central variant ID  \
# 0                        2022              8654.0
# 1                        2015              4025.0
# 2                        2021              8135.0
# 3                        2015              1579.0
# 4                        2015              1341.0
# ...                       ...                 ...
# 8364                     2012                 NaN
# 8365                     2008                 NaN
# 8366                     2014                 NaN
# 8367                     2018                 NaN
# 8368                     2017                 NaN
#
#                        Variant name Price of the used car Actual price  \
# 0     Turbo DCT Anniversary Edition          ₹ 11.50 Lakh
# 1            7 Seater Standard BSIV           ₹ 4.15 Lakh
# 2             Turbo XV Premium BSVI           ₹ 7.50 Lakh
# 3                       Sportz 1.1L           ₹ 3.98 Lakh
# 4                     1.2 VX i VTEC           ₹ 5.50 Lakh
# ...                             ...                   ...          ...
# 8364                         4x4 MT          ₹ 16.49 Lakh
# 8365                      Zxi BSIII           ₹ 3.30 Lakh
# 8366                           S MT           ₹ 4.25 Lakh
# 8367             1.4 Asta Dual Tone           ₹ 7.50 Lakh
# 8368                 Asta Option AT           ₹ 6.75 Lakh
#
#      Price saving  Fixed price details   Location   Central variant ID
# 0                                 None    chennai                  NaN
# 1                                 None    chennai                  NaN
# 2                                 None    chennai                  NaN
# 3                                 None    chennai                  NaN
# 4                                 None    chennai                  NaN
# ...            ...                 ...        ...                  ...
# 8364                              None  Bangalore               2253.0
# 8365                              None  Bangalore               4257.0
# 8366                              None  Bangalore               1188.0
# 8367                              None  Bangalore               5695.0
# 8368                              None  Bangalore               1523.0
#
# [8369 rows x 19 columns]

# %%
cardekho.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8369 entries, 0 to 8368
# Data columns (total 19 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   new_car_overview                 8369 non-null   object
#  1   new_car_feature                  8369 non-null   object
#  2   fuel type                        8369 non-null   object
#  3   Body type                        8369 non-null   object
#  4   Kilometers driven                8369 non-null   object
#  5   Transmission type                8369 non-null   object
#  6   Number of previous owners        8369 non-null   int64
#  7   Ownership details                8369 non-null   object
#  8   Original Equipment Manufacturer  8369 non-null   object
#  9   Car model                        8369 non-null   object
#  10  Year of car manufacture          8369 non-null   int64
#  11  Central variant ID               1419 non-null   float64
#  12  Variant name                     8369 non-null   object
#  13  Price of the used car            8369 non-null   object
#  14  Actual price                     8369 non-null   object
#  15  Price saving                     8369 non-null   object
#  16  Fixed price details              0 non-null      object
#  17  Location                         8369 non-null   object
#  18   Central variant ID              6950 non-null   float64
# dtypes: float64(2), int64(2), object(15)
# memory usage: 1.2+ MB

# %%
# Remove commas from values in the "Kilometers driven" column and then convert to int64
cardekho['Kilometers driven'] = cardekho['Kilometers driven'].str.replace(',', '').astype('int64')

# %%
cardekho['Year of car manufacture'] = pd.to_datetime(cardekho['Year of car manufacture'], format='%Y')

# %%
# Assuming 'cardekho' is your DataFrame

# Drop the last column using iloc
cardekho = cardekho.iloc[:, :-1]

# Display the DataFrame
print(cardekho)
# Out:
#                                        new_car_overview  \
# 0     {'heading': 'Car overview', 'top': [{'key': 'R...
# 1     {'heading': 'Car overview', 'top': [{'key': 'R...
# 2     {'heading': 'Car overview', 'top': [{'key': 'R...
# 3     {'heading': 'Car overview', 'top': [{'key': 'R...
# 4     {'heading': 'Car overview', 'top': [{'key': 'R...
# ...                                                 ...
# 8364  {'heading': 'Car overview', 'top': [{'key': 'R...
# 8365  {'heading': 'Car overview', 'top': [{'key': 'R...
# 8366  {'heading': 'Car overview', 'top': [{'key': 'R...
# 8367  {'heading': 'Car overview', 'top': [{'key': 'R...
# 8368  {'heading': 'Car overview', 'top': [{'key': 'R...
#
#                                         new_car_feature fuel type  Body type  \
# 0     {'heading': 'Features', 'top': [{'value': 'Pow...    Petrol        SUV
# 1     {'heading': 'Features', 'top': [{'value': 'Low...    Petrol   Minivans
# 2     {'heading': 'Features', 'top': [{'value': 'Pow...    Petrol        SUV
# 3     {'heading': 'Features', 'top': [{'value': 'Pow...    Petrol  Hatchback
# 4     {'heading': 'Features', 'top': [{'value': 'Pow...    Petrol  Hatchback
# ...                                                 ...       ...        ...
# 8364  {'heading': 'Features', 'top': [{'value': 'Pow...    Diesel        SUV
# 8365  {'heading': 'Features', 'top': [{'value': 'Pow...    Petrol      Sedan
# 8366  {'heading': 'Features', 'top': [{'value': 'Pow...    Petrol  Hatchback
# 8367  {'heading': 'Features', 'top': [{'value': 'Pow...    Diesel  Hatchback
# 8368  {'heading': 'Features', 'top': [{'value': 'Pow...    Petrol  Hatchback
#
#       Kilometers driven Transmission type  Number of previous owners  \
# 0                 20000         Automatic                          1
# 1                 20687            Manual                          1
# 2                 30000            Manual                          1
# 3                 59247            Manual                          1
# 4                 50000            Manual                          1
# ...                 ...               ...                        ...
# 8364             156039            Manual                          2
# 8365              56000            Manual                          2
# 8366              42000            Manual                          2
# 8367              93003            Manual                          1
# 8368              36000         Automatic                          2
#
#      Ownership details Original Equipment Manufacturer          Car model  \
# 0            1st Owner                             Kia          Kia Sonet
# 1            1st Owner                          Maruti        Maruti Eeco
# 2            1st Owner                          Nissan     Nissan Magnite
# 3            1st Owner                         Hyundai        Hyundai i10
# 4            1st Owner                           Honda         Honda Jazz
# ...                ...                             ...                ...
# 8364         2nd Owner                          Toyota    Toyota Fortuner
# 8365         2nd Owner                          Maruti         Maruti SX4
# 8366         2nd Owner                           Honda         Honda Brio
# 8367         1st Owner                         Hyundai        Hyundai i20
# 8368         2nd Owner                         Hyundai  Hyundai Grand i10
#
#      Year of car manufacture  Central variant ID  \
# 0                 2022-01-01              8654.0
# 1                 2015-01-01              4025.0
# 2                 2021-01-01              8135.0
# 3                 2015-01-01              1579.0
# 4                 2015-01-01              1341.0
# ...                      ...                 ...
# 8364              2012-01-01                 NaN
# 8365              2008-01-01                 NaN
# 8366              2014-01-01                 NaN
# 8367              2018-01-01                 NaN
# 8368              2017-01-01                 NaN
#
#                        Variant name Price of the used car Actual price  \
# 0     Turbo DCT Anniversary Edition          ₹ 11.50 Lakh
# 1            7 Seater Standard BSIV           ₹ 4.15 Lakh
# 2             Turbo XV Premium BSVI           ₹ 7.50 Lakh
# 3                       Sportz 1.1L           ₹ 3.98 Lakh
# 4                     1.2 VX i VTEC           ₹ 5.50 Lakh
# ...                             ...                   ...          ...
# 8364                         4x4 MT          ₹ 16.49 Lakh
# 8365                      Zxi BSIII           ₹ 3.30 Lakh
# 8366                           S MT           ₹ 4.25 Lakh
# 8367             1.4 Asta Dual Tone           ₹ 7.50 Lakh
# 8368                 Asta Option AT           ₹ 6.75 Lakh
#
#      Price saving  Fixed price details   Location
# 0                                 None    chennai
# 1                                 None    chennai
# 2                                 None    chennai
# 3                                 None    chennai
# 4                                 None    chennai
# ...            ...                 ...        ...
# 8364                              None  Bangalore
# 8365                              None  Bangalore
# 8366                              None  Bangalore
# 8367                              None  Bangalore
# 8368                              None  Bangalore
#
# [8369 rows x 18 columns]

# %%
cardekho
# Out:
#                                        new_car_overview  \
# 0     {'heading': 'Car overview', 'top': [{'key': 'R...
# 1     {'heading': 'Car overview', 'top': [{'key': 'R...
# 2     {'heading': 'Car overview', 'top': [{'key': 'R...
# 3     {'heading': 'Car overview', 'top': [{'key': 'R...
# 4     {'heading': 'Car overview', 'top': [{'key': 'R...
# ...                                                 ...
# 8364  {'heading': 'Car overview', 'top': [{'key': 'R...
# 8365  {'heading': 'Car overview', 'top': [{'key': 'R...
# 8366  {'heading': 'Car overview', 'top': [{'key': 'R...
# 8367  {'heading': 'Car overview', 'top': [{'key': 'R...
# 8368  {'heading': 'Car overview', 'top': [{'key': 'R...
#
#                                         new_car_feature fuel type  Body type  \
# 0     {'heading': 'Features', 'top': [{'value': 'Pow...    Petrol        SUV
# 1     {'heading': 'Features', 'top': [{'value': 'Low...    Petrol   Minivans
# 2     {'heading': 'Features', 'top': [{'value': 'Pow...    Petrol        SUV
# 3     {'heading': 'Features', 'top': [{'value': 'Pow...    Petrol  Hatchback
# 4     {'heading': 'Features', 'top': [{'value': 'Pow...    Petrol  Hatchback
# ...                                                 ...       ...        ...
# 8364  {'heading': 'Features', 'top': [{'value': 'Pow...    Diesel        SUV
# 8365  {'heading': 'Features', 'top': [{'value': 'Pow...    Petrol      Sedan
# 8366  {'heading': 'Features', 'top': [{'value': 'Pow...    Petrol  Hatchback
# 8367  {'heading': 'Features', 'top': [{'value': 'Pow...    Diesel  Hatchback
# 8368  {'heading': 'Features', 'top': [{'value': 'Pow...    Petrol  Hatchback
#
#       Kilometers driven Transmission type  Number of previous owners  \
# 0                 20000         Automatic                          1
# 1                 20687            Manual                          1
# 2                 30000            Manual                          1
# 3                 59247            Manual                          1
# 4                 50000            Manual                          1
# ...                 ...               ...                        ...
# 8364             156039            Manual                          2
# 8365              56000            Manual                          2
# 8366              42000            Manual                          2
# 8367              93003            Manual                          1
# 8368              36000         Automatic                          2
#
#      Ownership details Original Equipment Manufacturer          Car model  \
# 0            1st Owner                             Kia          Kia Sonet
# 1            1st Owner                          Maruti        Maruti Eeco
# 2            1st Owner                          Nissan     Nissan Magnite
# 3            1st Owner                         Hyundai        Hyundai i10
# 4            1st Owner                           Honda         Honda Jazz
# ...                ...                             ...                ...
# 8364         2nd Owner                          Toyota    Toyota Fortuner
# 8365         2nd Owner                          Maruti         Maruti SX4
# 8366         2nd Owner                           Honda         Honda Brio
# 8367         1st Owner                         Hyundai        Hyundai i20
# 8368         2nd Owner                         Hyundai  Hyundai Grand i10
#
#      Year of car manufacture  Central variant ID  \
# 0                 2022-01-01              8654.0
# 1                 2015-01-01              4025.0
# 2                 2021-01-01              8135.0
# 3                 2015-01-01              1579.0
# 4                 2015-01-01              1341.0
# ...                      ...                 ...
# 8364              2012-01-01                 NaN
# 8365              2008-01-01                 NaN
# 8366              2014-01-01                 NaN
# 8367              2018-01-01                 NaN
# 8368              2017-01-01                 NaN
#
#                        Variant name Price of the used car Actual price  \
# 0     Turbo DCT Anniversary Edition          ₹ 11.50 Lakh
# 1            7 Seater Standard BSIV           ₹ 4.15 Lakh
# 2             Turbo XV Premium BSVI           ₹ 7.50 Lakh
# 3                       Sportz 1.1L           ₹ 3.98 Lakh
# 4                     1.2 VX i VTEC           ₹ 5.50 Lakh
# ...                             ...                   ...          ...
# 8364                         4x4 MT          ₹ 16.49 Lakh
# 8365                      Zxi BSIII           ₹ 3.30 Lakh
# 8366                           S MT           ₹ 4.25 Lakh
# 8367             1.4 Asta Dual Tone           ₹ 7.50 Lakh
# 8368                 Asta Option AT           ₹ 6.75 Lakh
#
#      Price saving  Fixed price details   Location
# 0                                 None    chennai
# 1                                 None    chennai
# 2                                 None    chennai
# 3                                 None    chennai
# 4                                 None    chennai
# ...            ...                 ...        ...
# 8364                              None  Bangalore
# 8365                              None  Bangalore
# 8366                              None  Bangalore
# 8367                              None  Bangalore
# 8368                              None  Bangalore
#
# [8369 rows x 18 columns]

# %%
cardekho.new_car_overview
# Out:
# 0       {'heading': 'Car overview', 'top': [{'key': 'R...
# 1       {'heading': 'Car overview', 'top': [{'key': 'R...
# 2       {'heading': 'Car overview', 'top': [{'key': 'R...
# 3       {'heading': 'Car overview', 'top': [{'key': 'R...
# 4       {'heading': 'Car overview', 'top': [{'key': 'R...
#                               ...
# 8364    {'heading': 'Car overview', 'top': [{'key': 'R...
# 8365    {'heading': 'Car overview', 'top': [{'key': 'R...
# 8366    {'heading': 'Car overview', 'top': [{'key': 'R...
# 8367    {'heading': 'Car overview', 'top': [{'key': 'R...
# 8368    {'heading': 'Car overview', 'top': [{'key': 'R...
# Name: new_car_overview, Length: 8369, dtype: object

# %%
def to_get_overview(data):
    return {value['key']: value['value'] for value in data}

# Apply the transformation to cardekho.new_car_overview
cardekho.new_car_overview = cardekho.new_car_overview.apply(lambda x: to_get_overview(eval(x).get('top')))

# Create a new DataFrame from cardekho.new_car_overview
new_car_overview = pd.DataFrame(cardekho.new_car_overview.tolist())

# %%
new_car_overview
# Out:
#      Registration Year     Insurance Validity Fuel Type    Seats  \
# 0                 2022  Third Party insurance    Petrol  5 Seats
# 1             Feb 2015          Comprehensive    Petrol  7 Seats
# 2                 2021  Third Party insurance    Petrol  5 Seats
# 3             May 2015          Comprehensive    Petrol  5 Seats
# 4                 2015  Third Party insurance    Petrol  5 Seats
# ...                ...                    ...       ...      ...
# 8364          May 2012          Comprehensive    Diesel  7 Seats
# 8365          Jun 2008  Third Party insurance    Petrol  5 Seats
# 8366         Sept 2014          Comprehensive    Petrol  5 Seats
# 8367          Dec 2018          Comprehensive    Diesel  5 Seats
# 8368          May 2017          Comprehensive    Petrol  5 Seats
#
#         Kms Driven   RTO     Ownership Engine Displacement Transmission  \
# 0       20,000 Kms  TN02   First Owner              998 cc    Automatic
# 1       20,687 Kms  TN04   First Owner             1196 cc       Manual
# 2       30,000 Kms  TN22   First Owner              999 cc       Manual
# 3       59,247 Kms  TN11   First Owner             1086 cc       Manual
# 4       50,000 Kms  KA03   First Owner             1199 cc       Manual
# ...            ...   ...           ...                 ...          ...
# 8364  1,56,039 Kms  KA01  Second Owner             2982 cc       Manual
# 8365    56,000 Kms  KA02  Second Owner             1586 cc       Manual
# 8366    42,000 Kms  KA03  Second Owner             1198 cc       Manual
# 8367    93,003 Kms  KA03   First Owner             1396 cc       Manual
# 8368    36,000 Kms  KA04  Second Owner             1197 cc    Automatic
#
#       Year of Manufacture
# 0                  2022.0
# 1                  2015.0
# 2                  2021.0
# 3                  2015.0
# 4                  2015.0
# ...                   ...
# 8364               2012.0
# 8365               2008.0
# 8366               2014.0
# 8367               2018.0
# 8368               2017.0
#
# [8369 rows x 10 columns]

# %%
def to_get_features(data):
    extract = {'Features': [], "Comfort": [], "Interior":[], "Exterior": [] }
    for features in data['top']:
        extract['Features'].append(features['value'])
    try:
        for comfort in data['data'][0]['list']:
            extract['Comfort'].append(comfort['value'])
    except:
        extract['Comfort'].append('Not-Specified')
    try:
        for interior in data['data'][1]['list']:
            extract['Interior'].append(interior['value'])
    except:
        extract['Interior'].append('Not-Specified')
    try:
        for exterior in data['data'][2]['list']:
            extract['Exterior'].append(exterior['value'])
    except:
        extract['Exterior'].append(None)
    return extract

cardekho.new_car_feature = cardekho.new_car_feature.apply(lambda x: to_get_features(eval(x)))
new_car_feature = pd.DataFrame(cardekho.new_car_feature.tolist())
new_car_feature
# Out:
#                                                Features  \
# 0     [Power Steering, Power Windows Front, Air Cond...
# 1     [Low Fuel Warning Light, Accessory Power Outle...
# 2     [Power Steering, Power Windows Front, Air Cond...
# 3     [Power Steering, Power Windows Front, Air Cond...
# 4     [Power Steering, Power Windows Front, Air Cond...
# ...                                                 ...
# 8364  [Power Steering, Power Windows Front, Air Cond...
# 8365  [Power Steering, Power Windows Front, Air Cond...
# 8366  [Power Steering, Power Windows Front, Air Cond...
# 8367  [Power Steering, Power Windows Front, Air Cond...
# 8368  [Power Steering, Power Windows Front, Air Cond...
#
#                                                 Comfort  \
# 0     [Power Steering, Power Windows Front, Power Wi...
# 1     [Low Fuel Warning Light, Accessory Power Outle...
# 2     [Power Steering, Power Windows Front, Power Wi...
# 3     [Power Steering, Power Windows Front, Power Wi...
# 4     [Power Steering, Power Windows Front, Power Wi...
# ...                                                 ...
# 8364  [Power Steering, Power Windows Front, Power Wi...
# 8365  [Power Steering, Power Windows Front, Power Wi...
# 8366  [Power Steering, Power Windows Front, Power Wi...
# 8367  [Power Steering, Power Windows Front, Power Wi...
# 8368  [Power Steering, Power Windows Front, Power Wi...
#
#                                                Interior  \
# 0     [Air Conditioner, Heater, Adjustable Steering,...
# 1     [Heater, Digital Odometer, Electronic Multi Tr...
# 2     [Air Conditioner, Heater, Adjustable Steering,...
# 3     [Air Conditioner, Heater, Adjustable Steering,...
# 4     [Air Conditioner, Heater, Adjustable Steering,...
# ...                                                 ...
# 8364  [Air Conditioner, Heater, Adjustable Steering,...
# 8365  [Air Conditioner, Heater, Adjustable Steering,...
# 8366  [Air Conditioner, Heater, Digital Odometer, Ta...
# 8367  [Air Conditioner, Heater, Adjustable Steering,...
# 8368  [Air Conditioner, Heater, Adjustable Steering,...
#
#                                                Exterior
# 0     [Adjustable Head Lights, Fog Lights Front, Pow...
# 1     [Adjustable Head Lights, Manually Adjustable E...
# 2     [Adjustable Head Lights, Fog Lights Front, Pow...
# 3     [Adjustable Head Lights, Fog Lights Front, Man...
# 4     [Adjustable Head Lights, Fog Lights Front, Pow...
# ...                                                 ...
# 8364  [Adjustable Head Lights, Fog Lights Front, Pow...
# 8365  [Fog Lights Front, Fog Lights Rear, Power Adju...
# 8366  [Adjustable Head Lights, Power Adjustable Exte...
# 8367  [Adjustable Head Lights, Fog Lights Front, Pow...
# 8368  [Adjustable Head Lights, Fog Lights Front, Pow...
#
# [8369 rows x 4 columns]

# %%
pd.set_option('display.max_columns', 500)

# %%
car_data = pd.concat([cardekho, new_car_overview, new_car_feature], axis=1)
car_data.head()
# Out:
#                                     new_car_overview  \
# 0  {'Registration Year': '2022', 'Insurance Valid...
# 1  {'Registration Year': 'Feb 2015', 'Insurance V...
# 2  {'Registration Year': '2021', 'Insurance Valid...
# 3  {'Registration Year': 'May 2015', 'Insurance V...
# 4  {'Registration Year': '2015', 'Insurance Valid...
#
#                                      new_car_feature fuel type  Body type  \
# 0  {'Features': ['Power Steering', 'Power Windows...    Petrol        SUV
# 1  {'Features': ['Low Fuel Warning Light', 'Acces...    Petrol   Minivans
# 2  {'Features': ['Power Steering', 'Power Windows...    Petrol        SUV
# 3  {'Features': ['Power Steering', 'Power Windows...    Petrol  Hatchback
# 4  {'Features': ['Power Steering', 'Power Windows...    Petrol  Hatchback
#
#    Kilometers driven Transmission type  Number of previous owners  \
# 0              20000         Automatic                          1
# 1              20687            Manual                          1
# 2              30000            Manual                          1
# 3              59247            Manual                          1
# 4              50000            Manual                          1
#
#   Ownership details Original Equipment Manufacturer       Car model  \
# 0         1st Owner                             Kia       Kia Sonet
# 1         1st Owner                          Maruti     Maruti Eeco
# 2         1st Owner                          Nissan  Nissan Magnite
# 3         1st Owner                         Hyundai     Hyundai i10
# 4         1st Owner                           Honda      Honda Jazz
#
#   Year of car manufacture  Central variant ID                   Variant name  \
# 0              2022-01-01              8654.0  Turbo DCT Anniversary Edition
# 1              2015-01-01              4025.0         7 Seater Standard BSIV
# 2              2021-01-01              8135.0          Turbo XV Premium BSVI
# 3              2015-01-01              1579.0                    Sportz 1.1L
# 4              2015-01-01              1341.0                  1.2 VX i VTEC
#
#   Price of the used car Actual price Price saving  Fixed price details  \
# 0          ₹ 11.50 Lakh                                           None
# 1           ₹ 4.15 Lakh                                           None
# 2           ₹ 7.50 Lakh                                           None
# 3           ₹ 3.98 Lakh                                           None
# 4           ₹ 5.50 Lakh                                           None
#
#   Location Registration Year     Insurance Validity Fuel Type    Seats  \
# 0  chennai              2022  Third Party insurance    Petrol  5 Seats
# 1  chennai          Feb 2015          Comprehensive    Petrol  7 Seats
# 2  chennai              2021  Third Party insurance    Petrol  5 Seats
# 3  chennai          May 2015          Comprehensive    Petrol  5 Seats
# 4  chennai              2015  Third Party insurance    Petrol  5 Seats
#
#    Kms Driven   RTO    Ownership Engine Displacement Transmission  \
# 0  20,000 Kms  TN02  First Owner              998 cc    Automatic
# 1  20,687 Kms  TN04  First Owner             1196 cc       Manual
# 2  30,000 Kms  TN22  First Owner              999 cc       Manual
# 3  59,247 Kms  TN11  First Owner             1086 cc       Manual
# 4  50,000 Kms  KA03  First Owner             1199 cc       Manual
#
#    Year of Manufacture                                           Features  \
# 0               2022.0  [Power Steering, Power Windows Front, Air Cond...
# 1               2015.0  [Low Fuel Warning Light, Accessory Power Outle...
# 2               2021.0  [Power Steering, Power Windows Front, Air Cond...
# 3               2015.0  [Power Steering, Power Windows Front, Air Cond...
# 4               2015.0  [Power Steering, Power Windows Front, Air Cond...
#
#                                              Comfort  \
# 0  [Power Steering, Power Windows Front, Power Wi...
# 1  [Low Fuel Warning Light, Accessory Power Outle...
# 2  [Power Steering, Power Windows Front, Power Wi...
# 3  [Power Steering, Power Windows Front, Power Wi...
# 4  [Power Steering, Power Windows Front, Power Wi...
#
#                                             Interior  \
# 0  [Air Conditioner, Heater, Adjustable Steering,...
# 1  [Heater, Digital Odometer, Electronic Multi Tr...
# 2  [Air Conditioner, Heater, Adjustable Steering,...
# 3  [Air Conditioner, Heater, Adjustable Steering,...
# 4  [Air Conditioner, Heater, Adjustable Steering,...
#
#                                             Exterior
# 0  [Adjustable Head Lights, Fog Lights Front, Pow...
# 1  [Adjustable Head Lights, Manually Adjustable E...
# 2  [Adjustable Head Lights, Fog Lights Front, Pow...
# 3  [Adjustable Head Lights, Fog Lights Front, Man...
# 4  [Adjustable Head Lights, Fog Lights Front, Pow...

# %%
car_data= car_data.drop(columns = ['new_car_overview','new_car_feature'])

# %%
car_data
# Out:
#      fuel type  Body type  Kilometers driven Transmission type  \
# 0       Petrol        SUV              20000         Automatic
# 1       Petrol   Minivans              20687            Manual
# 2       Petrol        SUV              30000            Manual
# 3       Petrol  Hatchback              59247            Manual
# 4       Petrol  Hatchback              50000            Manual
# ...        ...        ...                ...               ...
# 8364    Diesel        SUV             156039            Manual
# 8365    Petrol      Sedan              56000            Manual
# 8366    Petrol  Hatchback              42000            Manual
# 8367    Diesel  Hatchback              93003            Manual
# 8368    Petrol  Hatchback              36000         Automatic
#
#       Number of previous owners Ownership details  \
# 0                             1         1st Owner
# 1                             1         1st Owner
# 2                             1         1st Owner
# 3                             1         1st Owner
# 4                             1         1st Owner
# ...                         ...               ...
# 8364                          2         2nd Owner
# 8365                          2         2nd Owner
# 8366                          2         2nd Owner
# 8367                          1         1st Owner
# 8368                          2         2nd Owner
#
#      Original Equipment Manufacturer          Car model  \
# 0                                Kia          Kia Sonet
# 1                             Maruti        Maruti Eeco
# 2                             Nissan     Nissan Magnite
# 3                            Hyundai        Hyundai i10
# 4                              Honda         Honda Jazz
# ...                              ...                ...
# 8364                          Toyota    Toyota Fortuner
# 8365                          Maruti         Maruti SX4
# 8366                           Honda         Honda Brio
# 8367                         Hyundai        Hyundai i20
# 8368                         Hyundai  Hyundai Grand i10
#
#      Year of car manufacture  Central variant ID  \
# 0                 2022-01-01              8654.0
# 1                 2015-01-01              4025.0
# 2                 2021-01-01              8135.0
# 3                 2015-01-01              1579.0
# 4                 2015-01-01              1341.0
# ...                      ...                 ...
# 8364              2012-01-01                 NaN
# 8365              2008-01-01                 NaN
# 8366              2014-01-01                 NaN
# 8367              2018-01-01                 NaN
# 8368              2017-01-01                 NaN
#
#                        Variant name Price of the used car Actual price  \
# 0     Turbo DCT Anniversary Edition          ₹ 11.50 Lakh
# 1            7 Seater Standard BSIV           ₹ 4.15 Lakh
# 2             Turbo XV Premium BSVI           ₹ 7.50 Lakh
# 3                       Sportz 1.1L           ₹ 3.98 Lakh
# 4                     1.2 VX i VTEC           ₹ 5.50 Lakh
# ...                             ...                   ...          ...
# 8364                         4x4 MT          ₹ 16.49 Lakh
# 8365                      Zxi BSIII           ₹ 3.30 Lakh
# 8366                           S MT           ₹ 4.25 Lakh
# 8367             1.4 Asta Dual Tone           ₹ 7.50 Lakh
# 8368                 Asta Option AT           ₹ 6.75 Lakh
#
#      Price saving  Fixed price details   Location Registration Year  \
# 0                                 None    chennai              2022
# 1                                 None    chennai          Feb 2015
# 2                                 None    chennai              2021
# 3                                 None    chennai          May 2015
# 4                                 None    chennai              2015
# ...            ...                 ...        ...               ...
# 8364                              None  Bangalore          May 2012
# 8365                              None  Bangalore          Jun 2008
# 8366                              None  Bangalore         Sept 2014
# 8367                              None  Bangalore          Dec 2018
# 8368                              None  Bangalore          May 2017
#
#          Insurance Validity Fuel Type    Seats    Kms Driven   RTO  \
# 0     Third Party insurance    Petrol  5 Seats    20,000 Kms  TN02
# 1             Comprehensive    Petrol  7 Seats    20,687 Kms  TN04
# 2     Third Party insurance    Petrol  5 Seats    30,000 Kms  TN22
# 3             Comprehensive    Petrol  5 Seats    59,247 Kms  TN11
# 4     Third Party insurance    Petrol  5 Seats    50,000 Kms  KA03
# ...                     ...       ...      ...           ...   ...
# 8364          Comprehensive    Diesel  7 Seats  1,56,039 Kms  KA01
# 8365  Third Party insurance    Petrol  5 Seats    56,000 Kms  KA02
# 8366          Comprehensive    Petrol  5 Seats    42,000 Kms  KA03
# 8367          Comprehensive    Diesel  5 Seats    93,003 Kms  KA03
# 8368          Comprehensive    Petrol  5 Seats    36,000 Kms  KA04
#
#          Ownership Engine Displacement Transmission  Year of Manufacture  \
# 0      First Owner              998 cc    Automatic               2022.0
# 1      First Owner             1196 cc       Manual               2015.0
# 2      First Owner              999 cc       Manual               2021.0
# 3      First Owner             1086 cc       Manual               2015.0
# 4      First Owner             1199 cc       Manual               2015.0
# ...            ...                 ...          ...                  ...
# 8364  Second Owner             2982 cc       Manual               2012.0
# 8365  Second Owner             1586 cc       Manual               2008.0
# 8366  Second Owner             1198 cc       Manual               2014.0
# 8367   First Owner             1396 cc       Manual               2018.0
# 8368  Second Owner             1197 cc    Automatic               2017.0
#
#                                                Features  \
# 0     [Power Steering, Power Windows Front, Air Cond...
# 1     [Low Fuel Warning Light, Accessory Power Outle...
# 2     [Power Steering, Power Windows Front, Air Cond...
# 3     [Power Steering, Power Windows Front, Air Cond...
# 4     [Power Steering, Power Windows Front, Air Cond...
# ...                                                 ...
# 8364  [Power Steering, Power Windows Front, Air Cond...
# 8365  [Power Steering, Power Windows Front, Air Cond...
# 8366  [Power Steering, Power Windows Front, Air Cond...
# 8367  [Power Steering, Power Windows Front, Air Cond...
# 8368  [Power Steering, Power Windows Front, Air Cond...
#
#                                                 Comfort  \
# 0     [Power Steering, Power Windows Front, Power Wi...
# 1     [Low Fuel Warning Light, Accessory Power Outle...
# 2     [Power Steering, Power Windows Front, Power Wi...
# 3     [Power Steering, Power Windows Front, Power Wi...
# 4     [Power Steering, Power Windows Front, Power Wi...
# ...                                                 ...
# 8364  [Power Steering, Power Windows Front, Power Wi...
# 8365  [Power Steering, Power Windows Front, Power Wi...
# 8366  [Power Steering, Power Windows Front, Power Wi...
# 8367  [Power Steering, Power Windows Front, Power Wi...
# 8368  [Power Steering, Power Windows Front, Power Wi...
#
#                                                Interior  \
# 0     [Air Conditioner, Heater, Adjustable Steering,...
# 1     [Heater, Digital Odometer, Electronic Multi Tr...
# 2     [Air Conditioner, Heater, Adjustable Steering,...
# 3     [Air Conditioner, Heater, Adjustable Steering,...
# 4     [Air Conditioner, Heater, Adjustable Steering,...
# ...                                                 ...
# 8364  [Air Conditioner, Heater, Adjustable Steering,...
# 8365  [Air Conditioner, Heater, Adjustable Steering,...
# 8366  [Air Conditioner, Heater, Digital Odometer, Ta...
# 8367  [Air Conditioner, Heater, Adjustable Steering,...
# 8368  [Air Conditioner, Heater, Adjustable Steering,...
#
#                                                Exterior
# 0     [Adjustable Head Lights, Fog Lights Front, Pow...
# 1     [Adjustable Head Lights, Manually Adjustable E...
# 2     [Adjustable Head Lights, Fog Lights Front, Pow...
# 3     [Adjustable Head Lights, Fog Lights Front, Man...
# 4     [Adjustable Head Lights, Fog Lights Front, Pow...
# ...                                                 ...
# 8364  [Adjustable Head Lights, Fog Lights Front, Pow...
# 8365  [Fog Lights Front, Fog Lights Rear, Power Adju...
# 8366  [Adjustable Head Lights, Power Adjustable Exte...
# 8367  [Adjustable Head Lights, Fog Lights Front, Pow...
# 8368  [Adjustable Head Lights, Fog Lights Front, Pow...
#
# [8369 rows x 30 columns]

# %%
import re

# Define the convert_price function
def convert_price(value):
    if 'Lakh' in value:
        value = re.sub(r'[^\d.]', '', value)  # Remove non-numeric characters except '.'
        value = float(value) * 100000  # 1 Lakh = 100,000
    elif 'Crore' in value:
        value = re.sub(r'[^\d.]', '', value)  # Remove non-numeric characters except '.'
        value = float(value) * 10000000  # 1 Crore = 10,000,000
    else:
        value = re.sub(r'[^\d.]', '', value)  # Remove non-numeric characters except '.'
        value = float(value)
    return value

# Apply the convert_price function to the 'Price' column of the DataFrame
car_data['Price of the used car'] = car_data['Price of the used car'].apply(lambda x: convert_price(x))

# %%
car_data
# Out:
#      fuel type  Body type  Kilometers driven Transmission type  \
# 0       Petrol        SUV              20000         Automatic
# 1       Petrol   Minivans              20687            Manual
# 2       Petrol        SUV              30000            Manual
# 3       Petrol  Hatchback              59247            Manual
# 4       Petrol  Hatchback              50000            Manual
# ...        ...        ...                ...               ...
# 8364    Diesel        SUV             156039            Manual
# 8365    Petrol      Sedan              56000            Manual
# 8366    Petrol  Hatchback              42000            Manual
# 8367    Diesel  Hatchback              93003            Manual
# 8368    Petrol  Hatchback              36000         Automatic
#
#       Number of previous owners Ownership details  \
# 0                             1         1st Owner
# 1                             1         1st Owner
# 2                             1         1st Owner
# 3                             1         1st Owner
# 4                             1         1st Owner
# ...                         ...               ...
# 8364                          2         2nd Owner
# 8365                          2         2nd Owner
# 8366                          2         2nd Owner
# 8367                          1         1st Owner
# 8368                          2         2nd Owner
#
#      Original Equipment Manufacturer          Car model  \
# 0                                Kia          Kia Sonet
# 1                             Maruti        Maruti Eeco
# 2                             Nissan     Nissan Magnite
# 3                            Hyundai        Hyundai i10
# 4                              Honda         Honda Jazz
# ...                              ...                ...
# 8364                          Toyota    Toyota Fortuner
# 8365                          Maruti         Maruti SX4
# 8366                           Honda         Honda Brio
# 8367                         Hyundai        Hyundai i20
# 8368                         Hyundai  Hyundai Grand i10
#
#      Year of car manufacture  Central variant ID  \
# 0                 2022-01-01              8654.0
# 1                 2015-01-01              4025.0
# 2                 2021-01-01              8135.0
# 3                 2015-01-01              1579.0
# 4                 2015-01-01              1341.0
# ...                      ...                 ...
# 8364              2012-01-01                 NaN
# 8365              2008-01-01                 NaN
# 8366              2014-01-01                 NaN
# 8367              2018-01-01                 NaN
# 8368              2017-01-01                 NaN
#
#                        Variant name  Price of the used car Actual price  \
# 0     Turbo DCT Anniversary Edition              1150000.0
# 1            7 Seater Standard BSIV               415000.0
# 2             Turbo XV Premium BSVI               750000.0
# 3                       Sportz 1.1L               398000.0
# 4                     1.2 VX i VTEC               550000.0
# ...                             ...                    ...          ...
# 8364                         4x4 MT              1649000.0
# 8365                      Zxi BSIII               330000.0
# 8366                           S MT               425000.0
# 8367             1.4 Asta Dual Tone               750000.0
# 8368                 Asta Option AT               675000.0
#
#      Price saving  Fixed price details   Location Registration Year  \
# 0                                 None    chennai              2022
# 1                                 None    chennai          Feb 2015
# 2                                 None    chennai              2021
# 3                                 None    chennai          May 2015
# 4                                 None    chennai              2015
# ...            ...                 ...        ...               ...
# 8364                              None  Bangalore          May 2012
# 8365                              None  Bangalore          Jun 2008
# 8366                              None  Bangalore         Sept 2014
# 8367                              None  Bangalore          Dec 2018
# 8368                              None  Bangalore          May 2017
#
#          Insurance Validity Fuel Type    Seats    Kms Driven   RTO  \
# 0     Third Party insurance    Petrol  5 Seats    20,000 Kms  TN02
# 1             Comprehensive    Petrol  7 Seats    20,687 Kms  TN04
# 2     Third Party insurance    Petrol  5 Seats    30,000 Kms  TN22
# 3             Comprehensive    Petrol  5 Seats    59,247 Kms  TN11
# 4     Third Party insurance    Petrol  5 Seats    50,000 Kms  KA03
# ...                     ...       ...      ...           ...   ...
# 8364          Comprehensive    Diesel  7 Seats  1,56,039 Kms  KA01
# 8365  Third Party insurance    Petrol  5 Seats    56,000 Kms  KA02
# 8366          Comprehensive    Petrol  5 Seats    42,000 Kms  KA03
# 8367          Comprehensive    Diesel  5 Seats    93,003 Kms  KA03
# 8368          Comprehensive    Petrol  5 Seats    36,000 Kms  KA04
#
#          Ownership Engine Displacement Transmission  Year of Manufacture  \
# 0      First Owner              998 cc    Automatic               2022.0
# 1      First Owner             1196 cc       Manual               2015.0
# 2      First Owner              999 cc       Manual               2021.0
# 3      First Owner             1086 cc       Manual               2015.0
# 4      First Owner             1199 cc       Manual               2015.0
# ...            ...                 ...          ...                  ...
# 8364  Second Owner             2982 cc       Manual               2012.0
# 8365  Second Owner             1586 cc       Manual               2008.0
# 8366  Second Owner             1198 cc       Manual               2014.0
# 8367   First Owner             1396 cc       Manual               2018.0
# 8368  Second Owner             1197 cc    Automatic               2017.0
#
#                                                Features  \
# 0     [Power Steering, Power Windows Front, Air Cond...
# 1     [Low Fuel Warning Light, Accessory Power Outle...
# 2     [Power Steering, Power Windows Front, Air Cond...
# 3     [Power Steering, Power Windows Front, Air Cond...
# 4     [Power Steering, Power Windows Front, Air Cond...
# ...                                                 ...
# 8364  [Power Steering, Power Windows Front, Air Cond...
# 8365  [Power Steering, Power Windows Front, Air Cond...
# 8366  [Power Steering, Power Windows Front, Air Cond...
# 8367  [Power Steering, Power Windows Front, Air Cond...
# 8368  [Power Steering, Power Windows Front, Air Cond...
#
#                                                 Comfort  \
# 0     [Power Steering, Power Windows Front, Power Wi...
# 1     [Low Fuel Warning Light, Accessory Power Outle...
# 2     [Power Steering, Power Windows Front, Power Wi...
# 3     [Power Steering, Power Windows Front, Power Wi...
# 4     [Power Steering, Power Windows Front, Power Wi...
# ...                                                 ...
# 8364  [Power Steering, Power Windows Front, Power Wi...
# 8365  [Power Steering, Power Windows Front, Power Wi...
# 8366  [Power Steering, Power Windows Front, Power Wi...
# 8367  [Power Steering, Power Windows Front, Power Wi...
# 8368  [Power Steering, Power Windows Front, Power Wi...
#
#                                                Interior  \
# 0     [Air Conditioner, Heater, Adjustable Steering,...
# 1     [Heater, Digital Odometer, Electronic Multi Tr...
# 2     [Air Conditioner, Heater, Adjustable Steering,...
# 3     [Air Conditioner, Heater, Adjustable Steering,...
# 4     [Air Conditioner, Heater, Adjustable Steering,...
# ...                                                 ...
# 8364  [Air Conditioner, Heater, Adjustable Steering,...
# 8365  [Air Conditioner, Heater, Adjustable Steering,...
# 8366  [Air Conditioner, Heater, Digital Odometer, Ta...
# 8367  [Air Conditioner, Heater, Adjustable Steering,...
# 8368  [Air Conditioner, Heater, Adjustable Steering,...
#
#                                                Exterior
# 0     [Adjustable Head Lights, Fog Lights Front, Pow...
# 1     [Adjustable Head Lights, Manually Adjustable E...
# 2     [Adjustable Head Lights, Fog Lights Front, Pow...
# 3     [Adjustable Head Lights, Fog Lights Front, Man...
# 4     [Adjustable Head Lights, Fog Lights Front, Pow...
# ...                                                 ...
# 8364  [Adjustable Head Lights, Fog Lights Front, Pow...
# 8365  [Fog Lights Front, Fog Lights Rear, Power Adju...
# 8366  [Adjustable Head Lights, Power Adjustable Exte...
# 8367  [Adjustable Head Lights, Fog Lights Front, Pow...
# 8368  [Adjustable Head Lights, Fog Lights Front, Pow...
#
# [8369 rows x 30 columns]

# %%
import matplotlib.pyplot as plt

# Define the list of columns you want to plot
columns_to_plot = ['fuel type', 'Body type', 'Transmission type', 'Number of previous owners',
                   'Ownership details', 'Original Equipment Manufacturer', 'Car model',
                   'Year of car manufacture', 'Central variant ID', 'Variant name', 'Location']

# Plot the frequency of values for each column
for column in columns_to_plot:
    # Get the frequency of each value in the column
    col_count = car_data[column].value_counts()

    # Plotting the bar plot
    plt.figure(figsize=(10, 6))
    col_count.plot(kind='bar')  # Plot the frequency of values
    plt.title(f'Frequency of {column} Values')
    plt.xlabel(column)
    plt.ylabel('Frequency')
    plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
    plt.show()

# %%
import matplotlib.pyplot as plt

# Define the list of columns you want to create scatter plots against
columns_to_plot = ['fuel type', 'Body type', 'Kilometers driven', 'Transmission type',
                   'Number of previous owners', 'Ownership details', 'Original Equipment Manufacturer',
                   'Car model', 'Year of car manufacture', 'Central variant ID', 'Variant name', 'Location', 'Current_Year', 'No_of_Years', 'Registration Year',
                   'Insurance Validity', 'Fuel Type', 'Seats', 'Kms Driven', 'RTO', 'Ownership',
                   'Engine Displacement', 'Transmission', 'Year of Manufacture', 'Features', 'Comfort',
                   'Interior', 'Exterior']

# Plot scatter plots for 'Price of the used car' against each column
for column in columns_to_plot:
    plt.figure(figsize=(10, 6))
    plt.scatter(car_data['Price of the used car'], car_data[column], alpha=0.5)
    plt.title(f'Scatter Plot: Price of the used car vs {column}')
    plt.xlabel('Price of the used car')
    plt.ylabel(column)
    plt.grid(True)
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Current_Year'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-104-063251bb420b> in <cell line: 12>()
#      12 for column in columns_to_plot:
#      13     plt.figure(figsize=(10, 6))
# ---> 14     plt.scatter(car_data['Price of the used car'], car_data[column], alpha=0.5)
#      15     plt.title(f'Scatter Plot: Price of the used car vs {column}')
#      16     plt.xlabel('Price of the used car')
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3805             if self.columns.nlevels > 1:
#    3806                 return self._getitem_multilevel(key)
# -> 3807             indexer = self.columns.get_loc(key)
#    3808             if is_integer(indexer):
#    3809                 indexer = [indexer]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
# -> 3804                 raise KeyError(key) from err
#    3805             except TypeError:
#    3806                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'Current_Year'

# %%
car_data= car_data.drop(columns = ['Actual price'])

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Select numerical columns for correlation analysis
numerical_columns = ['Kilometers driven', 'Number of previous owners', 'Year of car manufacture',
                     'Price of the used car', 'Current_Year',
                     'No_of_Years', 'Registration Year', 'Seats', 'Kms Driven', 'Engine Displacement',
                     'Year of Manufacture']

# Filter the numerical columns from the DataFrame
numerical_data = car_data[numerical_columns]

# Compute the correlation matrix
correlation_matrix = numerical_data.corr()

# Set up the matplotlib figure
plt.figure(figsize=(12, 10))

# Plot the heatmap
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")

# Customize the plot
plt.title('Correlation Matrix of Numerical Variables')
plt.xticks(rotation=45, ha='right')
plt.yticks(rotation=45)
plt.tight_layout()

# Show plot
plt.show()

# %%
car_data

# %%
# Select categorical columns
categorical_columns = car_data.select_dtypes(include=['object']).columns.tolist()

# Select numeric columns
numeric_columns = car_data.select_dtypes(include=['int64', 'float64']).columns.tolist()

# Print the lists
print("Categorical Columns:", categorical_columns)
print("Numeric Columns:", numeric_columns)
# Out:
# Categorical Columns: ['Ownership details', 'Original Equipment Manufacturer', 'Car model', 'Variant name', 'Actual price', 'Price saving ', 'Fixed price details', 'Registration Year', 'Fuel Type', 'RTO', 'Ownership', 'Engine Displacement', 'Transmission', 'Features', 'Exterior']
# Numeric Columns: ['fuel type', 'Body type', 'Kilometers driven', 'Transmission type', 'Number of previous owners', 'Central variant ID', 'Price of the used car', 'Location', 'Insurance Validity', 'Seats', 'num_Comfort', 'num_Interior', 'num_features']

# %%
print(car_data.columns)

# %%
car_data = car_data.drop(columns=['Price saving '])

# %%
car_data['Year of car manufacture'] = pd.to_datetime(car_data['Year of car manufacture'], format='%Y')

# %%
car_data['Age of the Cars'] = current_year - car_data['Year of car manufacture'].dt.year

# %%
from datetime import datetime

# Determine the current year
current_year = datetime.now().year

# Calculate the age of the cars
car_data['Age of the Cars'] = current_year - car_data['Year of car manufacture']

# Convert Age of the Cars to Integer
car_data['Age of the Cars'] = car_data['Age of the Cars'].astype(int)

# %%
# Drop the 'Kms Driven' column from the DataFrame
car_data = car_data.drop(columns=['Kms Driven'])

# %%
# List of columns to drop
columns_to_drop = ['Features', 'Comfort', 'Interior', 'Exterior']

# Drop the specified columns from the DataFrame
car_data = car_data.drop(columns=columns_to_drop)

# %%
columns_to_drop = ['Transmission',	'Year of Manufacture']

# Drop the specified columns from the DataFrame
car_data = car_data.drop(columns=columns_to_drop)

# %%
columns_to_drop = ['Registration Year',	'Year of car manufacture']

# Drop the specified columns from the DataFrame
car_data = car_data.drop(columns=columns_to_drop)

# %%
columns_to_drop = ['Ownership details']

# Drop the specified columns from the DataFrame
car_data = car_data.drop(columns=columns_to_drop)

# %%
car_data

# %%
# Selecting categorical columns
categorical_columns = car_data.select_dtypes(include=['object']).columns.tolist()

# Selecting numeric columns
numeric_columns = car_data.select_dtypes(include=['int64', 'float64']).columns.tolist()

# Printing the lists
print("Categorical Columns:", categorical_columns)
print("Numeric Columns:", numeric_columns)

# %%
columns_to_count = ['fuel type', 'Body type', 'Transmission type',
                    'Original Equipment Manufacturer', 'Car model', 'Variant name', 'Location',
                    'Fuel Type', 'Seats', 'RTO', 'Ownership', 'Engine Displacement']

for column in columns_to_count:
    print(f"Value counts for {column}:")
    print(car_data[column].value_counts())
    print("\n")
# Out:
# Value counts for fuel type:
# 0    5554
# 1    2673
# 2      98
# 3      28
# 4      16
# Name: fuel type, dtype: int64
#
#
# Value counts for Body type:
# 0.0    3567
# 1.0    2225
# 2.0    2174
# 3.0     352
# 4.0      23
# 6.0      14
# 5.0      10
# Name: Body type, dtype: int64
#
#
# Value counts for Transmission type:
# 0    6052
# 1    2317
# Name: Transmission type, dtype: int64
#
#
# Value counts for Original Equipment Manufacturer:
# Maruti                2252
# Hyundai               1651
# Honda                  865
# Tata                   431
# Mahindra               377
# Toyota                 325
# Renault                312
# Ford                   311
# Volkswagen             294
# Mercedes-Benz          245
# BMW                    184
# Skoda                  161
# Kia                    158
# Audi                   156
# Jeep                   112
# MG                      90
# Nissan                  78
# Chevrolet               76
# Datsun                  74
# Land Rover              44
# Volvo                   41
# Jaguar                  35
# Fiat                    31
# Mitsubishi              14
# Mini                    12
# Citroen                  8
# Porsche                  6
# Isuzu                    5
# Mahindra Renault         5
# Lexus                    5
# Mahindra Ssangyong       4
# Hindustan Motors         4
# Opel                     3
# Name: Original Equipment Manufacturer, dtype: int64
#
#
# Value counts for Car model:
# Honda City                       370
# Maruti Swift                     350
# Hyundai i20                      331
# Maruti Baleno                    295
# Hyundai Grand i10                260
#                                 ...
# Maruti Celerio Tour 2018-2021      1
# Toyota Corolla                     1
# Chevrolet Aveo U-VA                1
# Hyundai Kona                       1
# Audi A3 cabriolet                  1
# Name: Car model, Length: 315, dtype: int64
#
#
# Value counts for Variant name:
# VXI                                 337
# LXI                                 145
# Sportz                               97
# VDI                                  78
# Magna                                77
#                                    ...
# GT 630i M Sport                       1
# LX 4-Str Convert Top Diesel BSVI      1
# HSE Luxury 2.0 SD4                    1
# 1.2 Revotron XZ Option                1
# 1.4 Asta Dual Tone                    1
# Name: Variant name, Length: 2157, dtype: int64
#
#
# Value counts for Location:
# 3    1485
# 1    1483
# 2    1481
# 0    1419
# 4    1381
# 5    1120
# Name: Location, dtype: int64
#
#
# Value counts for Fuel Type:
# Petrol      5554
# Diesel      2673
# CNG           98
# Electric      28
# LPG           16
# Name: Fuel Type, dtype: int64
#
#
# Value counts for Seats:
# 5.0     7354
# 7.0      728
# 6.0      103
# 4.0       93
# 8.0       62
# 9.0       11
# 2.0        7
# 10.0       5
# Name: Seats, dtype: int64
#
#
# Value counts for RTO:
# WB02    452
# RJ14    367
# TS07    282
# KA03    244
# TS08    244
#        ...
# HR10      1
# DL16      1
# PB03      1
# HR24      1
# KA33      1
# Name: RTO, Length: 465, dtype: int64
#
#
# Value counts for Ownership:
# First Owner     5882
# Second Owner    1982
# Third Owner      374
# Fourth Owner      80
# Fifth Owner       19
# Name: Ownership, dtype: int64
#
#
# Value counts for Engine Displacement:
# 1197 cc    1607
# 998 cc      640
# 1199 cc     489
# 1497 cc     451
# 1248 cc     424
#            ...
# 2956 cc       1
# 1468 cc       1
# 4134 cc       1
# 2112 cc       1
# 1108 cc       1
# Name: Engine Displacement, Length: 150, dtype: int64

# %%
car_data['fuel type'] = car_data['fuel type'].map({'Petrol':0,'Diesel':1,'Cng':2,'Electric':3,'Lpg':4})

# %%
car_data['Transmission type'] = car_data['Transmission type'].map({'Manual':0,'Automatic':1})

# %%
car_data['Location'] = car_data['Location'].map({'chennai':0,'Hyderabad':1,'Bangalore':2,'Delhi':3,'Kolkata':4,'Jaipur':5})

# %%
car_data['Seats'] = car_data['Seats'].map({'5 Seats':5,
    '7 Seats':7,
    '6 Seats':6,
    '4 Seats':4,
    '8 Seats':8,
    '9 Seats':9,
    '2 Seats':2,
    '10 Seats':10})

# %%
car_data['Body type'] = car_data['Body type'].map({'Hatchback':0,'SUV':1,'Sedan':2,'MUV':3,'Minivans':4,'Coupe':5,'Convertibles':6,'Pickup Trucks':6,'Hybrids':6,'Wagon':6})

# %%
car_data.head(1)
# Out:
#    fuel type  Body type  Kilometers driven  Transmission type  \
# 0          0        1.0              20000                  1
#
#    Number of previous owners Ownership details  \
# 0                          1         1st Owner
#
#   Original Equipment Manufacturer  Car model Year of car manufacture  \
# 0                             Kia  Kia Sonet              2022-01-01
#
#    Central variant ID                   Variant name  Price of the used car  \
# 0              8654.0  Turbo DCT Anniversary Edition              1150000.0
#
#   Actual price Price saving  Fixed price details  Location Registration Year  \
# 0                                           None         0              2022
#
#       Insurance Validity Fuel Type  Seats   RTO    Ownership  \
# 0  Third Party insurance    Petrol    5.0  TN02  First Owner
#
#   Engine Displacement Transmission  Year of Manufacture  \
# 0              998 cc    Automatic               2022.0
#
#                                             Features  \
# 0  [Power Steering, Power Windows Front, Air Cond...
#
#                                              Comfort  \
# 0  [Power Steering, Power Windows Front, Power Wi...
#
#                                             Interior  \
# 0  [Air Conditioner, Heater, Adjustable Steering,...
#
#                                             Exterior
# 0  [Adjustable Head Lights, Fog Lights Front, Pow...

# %%
# Create a label encoder object label_encoder = LabelEncoder() # Fit and transform the 'Original Equipment Manufacturer' column encoded_Original Equipment Manufacturer = label_encoder.fit_transform(car_data['Original Equipment Manufacturer']) # Replace the original 'Original Equipment Manufacturer' column with the encoded values car_data['Original Equipment Manufacturer_encoded'] = encoded_Original Equipment Manufacturer car_data.drop(columns = 'Original Equipment Manufacturer', inplace = True)

# %%
car_data['Insurance Validity'] = car_data['Insurance Validity'].map({'Third Party insurance':0,'Comprehensive':1,'Third Party':2,'Zero Dep':3,'Not Available':4, 1:5, 2:6})

# %%
# Assuming 'Features' is the column name # Calculate the number of features inside each list car_data['num_features'] = car_data['Features'].apply(lambda x: len(x)) # Drop the original 'Features' column if needed car_data.drop(columns='Features', inplace=True)

# %%
# Assuming 'Features' is the column name # Calculate the number of features inside each list car_data['num_features'] = car_data['Features'].apply(lambda x: len(eval(x))) car_data.drop(columns = 'Features', inplace = True)

# %%
car_data['num_features'] = car_data['Features'].apply(lambda x: len(x)) # Drop the original 'Features' column if needed car_data.drop(columns='Features', inplace=True)

# %%
car_data['num_features'] = car_data['Features'].apply(lambda x: len(eval(x)))
car_data.drop(columns = 'Features', inplace = True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-144-9310dadc8ae5> in <cell line: 1>()
# ----> 1 car_data['num_features'] = car_data['Features'].apply(lambda x: len(eval(x)))
#       2 car_data.drop(columns = 'Features', inplace = True)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4769         dtype: float64
#    4770         """
# -> 4771         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4772
#    4773     def _reduce(
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in apply(self)
#    1121
#    1122         # self.f is Callable
# -> 1123         return self.apply_standard()
#    1124
#    1125     def agg(self):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in apply_standard(self)
#    1172             else:
#    1173                 values = obj.astype(object)._values
# -> 1174                 mapped = lib.map_infer(
#    1175                     values,
#    1176                     f,
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-144-9310dadc8ae5> in <lambda>(x)
# ----> 1 car_data['num_features'] = car_data['Features'].apply(lambda x: len(eval(x)))
#       2 car_data.drop(columns = 'Features', inplace = True)
#
# TypeError: eval() arg 1 must be a string, bytes or code object

# %%
car_data['num_Comfort'] = car_data['Comfort'].apply(lambda x: len(x))
car_data.drop(columns='Comfort', inplace=True)

# %%
car_data['num_Interior'] = car_data['Interior'].apply(lambda x: len(x))
car_data.drop(columns='Interior', inplace=True)

# %%
# Assuming 'Features' is the column name # Calculate the number of features inside each list car_data['num_Exterior'] = car_data['Exterior'].apply(lambda x: len((x))) car_data.drop(columns = 'Exterior', inplace = True)

car_data.drop(columns = 'Year of Manufacture', inplace = True)

# %%
#car_data['Ownership details'] = car_data['Ownership details'].map({'First Owner':1,'Second Owner':2,'Third Owner':3,'Fourth Owner':4,'Fifth Owner':5})

# %%
# Create a label encoder object label_encoder = LabelEncoder() # Fit and transform the 'Original Equipment Manufacturer' column encoded_Original Equipment Manufacturer = label_encoder.fit_transform(car_data['Original Equipment Manufacturer']) # Replace the original 'Original Equipment Manufacturer' column with the encoded values car_data['Original Equipment Manufacturer_encoded'] = encoded_Original Equipment Manufacturer car_data.drop(columns = 'Original Equipment Manufacturer', inplace = True)

# %%
columns_to_drop = ['Ownership details', 'Actual price', 'Fixed price details', 'Fuel Type', 'Registration Year', 'Year of car manufacture', 'RTO', 'Transmission']
car_data.drop(columns=columns_to_drop, inplace=True)

# %%
car_data['Ownership'].value_counts()
# Out:
# First Owner     5882
# Second Owner    1982
# Third Owner      374
# Fourth Owner      80
# Fifth Owner       19
# Name: Ownership, dtype: int64

# %%
car=car_data.copy()

# %%
from sklearn.preprocessing import LabelEncoder

# Initialize LabelEncoder
label_encoder = LabelEncoder()

# Fit label encoder and transform the 'Ownership' column
car_data['Ownership_encoded'] = label_encoder.fit_transform(car_data['Ownership'])

# Display the value counts of the encoded column
print(car_data['Ownership_encoded'].value_counts())

# Display the mapping between original values and encoded values
print(dict(zip(label_encoder.classes_, label_encoder.transform(label_encoder.classes_))))
# Out:
# 1    5882
# 3    1982
# 4     374
# 2      80
# 5      32
# 0      19
# Name: Ownership_encoded, dtype: int64
# {'Fifth Owner': 0, 'First Owner': 1, 'Fourth Owner': 2, 'Second Owner': 3, 'Third Owner': 4, nan: 5}

# %%
car_data['num_Exterior'] = car_data['Exterior'].apply(lambda x: len(x))
car_data.drop(columns='Exterior', inplace=True)

# %%
car_data['num_Features'] = car_data['Features'].apply(lambda x: len(x))
car_data.drop(columns='Features', inplace=True)

# %%
# Assuming car_data is your DataFrame
car_data['Engine Displacement'] = car_data['Engine Displacement'].str.replace('cc', '')

# %%
# Define the mapping for the label changes
label_changes = {
    'First Owner': 1,
    'Second Owner': 2,
    'Third Owner': 3,
    'Fourth Owner': 4,
    'Fifth Owner': 5
}

# Replace the labels in the 'Ownership' column
car_data['Ownership'] = car_data['Ownership'].replace(label_changes)

# Check the updated value counts
print(car_data['Ownership'].value_counts())
# Out:
# 1.0    5882
# 2.0    1982
# 3.0     374
# 4.0      80
# 5.0      19
# Name: Ownership, dtype: int64

# %%
# Calculate the frequency of each variantName variantName_frequency = car_data['variantName'].value_counts(normalize=True) # Map the frequency values to the variantName column car_data['variantName_encoded'] = car_data['variantName'].map(variantName_frequency)

# %%
# Assuming car_data is your DataFrame
oem_value_counts = car_data['Original Equipment Manufacturer'].value_counts()
print(oem_value_counts)
# Out:
# Maruti                2252
# Hyundai               1651
# Honda                  865
# Tata                   431
# Mahindra               377
# Toyota                 325
# Renault                312
# Ford                   311
# Volkswagen             294
# Mercedes-Benz          245
# BMW                    184
# Skoda                  161
# Kia                    158
# Audi                   156
# Jeep                   112
# MG                      90
# Nissan                  78
# Chevrolet               76
# Datsun                  74
# Land Rover              44
# Volvo                   41
# Jaguar                  35
# Fiat                    31
# Mitsubishi              14
# Mini                    12
# Citroen                  8
# Porsche                  6
# Isuzu                    5
# Mahindra Renault         5
# Lexus                    5
# Mahindra Ssangyong       4
# Hindustan Motors         4
# Opel                     3
# Name: Original Equipment Manufacturer, dtype: int64

# %%
import category_encoders as ce
import category_encoders as ce

# Create a LeaveOneOutEncoder object
encoder = ce.LeaveOneOutEncoder()

# Assuming car_data is your DataFrame
target_column = 'Price of the used car'  # Replace 'Price' with the appropriate target column name

# Fit and transform the 'Original Equipment Manufacturer' column
car_data['OEM_encoded'] = encoder.fit_transform(car_data['Original Equipment Manufacturer'], car_data[target_column])

# Display the encoded values
print(car_data[['Original Equipment Manufacturer', 'OEM_encoded']])
# Out:
#      Original Equipment Manufacturer   OEM_encoded
# 0                                Kia  1.449777e+06
# 1                             Maruti  5.048179e+05
# 2                             Nissan  5.771039e+05
# 3                            Hyundai  6.060770e+05
# 4                              Honda  6.244477e+05
# ...                              ...           ...
# 8364                          Toyota  1.389006e+06
# 8365                          Maruti  5.048557e+05
# 8366                           Honda  6.245924e+05
# 8367                         Hyundai  6.058636e+05
# 8368                         Hyundai  6.059091e+05
#
# [8369 rows x 2 columns]

# %%
import category_encoders as ce
import category_encoders as ce

# Create a LeaveOneOutEncoder object
encoder = ce.LeaveOneOutEncoder()

# Assuming car_data is your DataFrame
target_column = 'Price of the used car'  # Replace 'Price' with the appropriate target column name

# Fit and transform the 'Original Equipment Manufacturer' column
car_data['model'] = encoder.fit_transform(car_data['Car model'], car_data[target_column])

# Display the encoded values
print(car_data[['Car model', 'model']])
# Out:
#               Car model         model
# 0             Kia Sonet  1.121861e+06
# 1           Maruti Eeco  4.000476e+05
# 2        Nissan Magnite  7.737000e+05
# 3           Hyundai i10  2.508681e+05
# 4            Honda Jazz  5.819279e+05
# ...                 ...           ...
# 8364    Toyota Fortuner  2.091814e+06
# 8365         Maruti SX4  1.827778e+05
# 8366         Honda Brio  3.369672e+05
# 8367        Hyundai i20  5.620939e+05
# 8368  Hyundai Grand i10  4.710039e+05
#
# [8369 rows x 2 columns]

# %%
# Drop the specified columns
car_data.drop(columns=['Original Equipment Manufacturer', 'Car model', 'Variant name'], inplace=True)

# %%
data=car_data.copy()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8369 entries, 0 to 8368
# Data columns (total 20 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   fuel type                  8369 non-null   int64
#  1   Body type                  8369 non-null   float64
#  2   Kilometers driven          8369 non-null   int64
#  3   Transmission type          8369 non-null   int64
#  4   Number of previous owners  8369 non-null   int64
#  5   Price of the used car      8369 non-null   float64
#  6   Price saving               8369 non-null   object
#  7   Location                   8369 non-null   int64
#  8   Insurance Validity         8369 non-null   float64
#  9   Seats                      8369 non-null   float64
#  10  Ownership                  8369 non-null   float64
#  11  Engine Displacement        8369 non-null   float64
#  12  num_Comfort                8369 non-null   int64
#  13  num_Interior               8369 non-null   int64
#  14  num_features               8369 non-null   int64
#  15  Ownership_encoded          8369 non-null   int64
#  16  num_Exterior               8369 non-null   int64
#  17  num_Features               8369 non-null   int64
#  18  OEM_encoded                8369 non-null   float64
#  19  model                      8369 non-null   float64
# dtypes: float64(8), int64(11), object(1)
# memory usage: 1.3+ MB

# %%
# Assuming car_data is your DataFrame
data['Engine Displacement'] = data['Engine Displacement'].astype('float64')

# %%
data.isnull().sum()
# Out:
# fuel type                    0
# Body type                    0
# Kilometers driven            0
# Transmission type            0
# Number of previous owners    0
# Price of the used car        0
# Price saving                 0
# Location                     0
# Insurance Validity           0
# Seats                        0
# Ownership                    0
# Engine Displacement          4
# num_Comfort                  0
# num_Interior                 0
# num_features                 0
# Ownership_encoded            0
# num_Exterior                 0
# num_Features                 0
# OEM_encoded                  0
# model                        0
# dtype: int64

# %%
# Assuming car_data is your DataFrame
columns_to_fill = ['Body type', 'Insurance Validity', 'Seats', 'Ownership', 'Engine Displacement']

# Fill missing values with mean for each specified column
for column in columns_to_fill:
  data[column].fillna(data[column].mean(), inplace=True)

# %%
data.isnull().sum()
# Out:
# fuel type                    0
# Body type                    0
# Kilometers driven            0
# Transmission type            0
# Number of previous owners    0
# Price of the used car        0
# Price saving                 0
# Location                     0
# Insurance Validity           0
# Seats                        0
# Ownership                    0
# Engine Displacement          0
# num_Comfort                  0
# num_Interior                 0
# num_features                 0
# Ownership_encoded            0
# num_Exterior                 0
# num_Features                 0
# OEM_encoded                  0
# model                        0
# dtype: int64

# %%
# Assuming data_table and df are your DataFrames
# Copying columns from data_table to df
# Create an empty DataFrame named df
df = pd.DataFrame()
df['fuel type'] = data['fuel type']
df['Body type'] = data['Body type']
df['Kilometers driven'] = data['Kilometers driven']
df['Transmission type'] = data['Transmission type']
df['Number of previous owners'] = data['Number of previous owners']
df['Price'] = data['Price of the used car']
df['Location'] = data['Location']
df['Insurance Validity'] = data['Insurance Validity']
df['Seats'] = data['Seats']
df['Ownership'] = data['Ownership']
df['Engine Displacement'] = data['Engine Displacement']
df['num_Comfort'] = data['num_Comfort']
df['num_Interior'] = data['num_Interior']
df['num_features'] = data['num_features']
df['Ownership_encoded'] = data['Ownership_encoded']
df['num_Exterior'] = data['num_Exterior']
df['num_Features'] = data['num_Features']
df['OEM_encoded'] = data['OEM_encoded']
df['model'] = data['model']

# %%
X = df.drop('Price',axis=1)
y = df['Price']

# %%
X
# Out:
#       fuel type  Body type  Kilometers driven  Transmission type  \
# 0             0        1.0              20000                  1
# 1             0        4.0              20687                  0
# 2             0        1.0              30000                  0
# 3             0        0.0              59247                  0
# 4             0        0.0              50000                  0
# ...         ...        ...                ...                ...
# 8364          1        1.0             156039                  0
# 8365          0        2.0              56000                  0
# 8366          0        0.0              42000                  0
# 8367          1        0.0              93003                  0
# 8368          0        0.0              36000                  1
#
#       Number of previous owners  Location  Insurance Validity  Seats  \
# 0                             1         0                 0.0    5.0
# 1                             1         0                 1.0    7.0
# 2                             1         0                 0.0    5.0
# 3                             1         0                 1.0    5.0
# 4                             1         0                 0.0    5.0
# ...                         ...       ...                 ...    ...
# 8364                          2         2                 1.0    7.0
# 8365                          2         2                 0.0    5.0
# 8366                          2         2                 1.0    5.0
# 8367                          1         2                 1.0    5.0
# 8368                          2         2                 1.0    5.0
#
#       Ownership  Engine Displacement  num_Comfort  num_Interior  num_features  \
# 0           1.0                998.0           20            13             9
# 1           1.0               1196.0            3             5             8
# 2           1.0                999.0           22            13             9
# 3           1.0               1086.0            8             9             9
# 4           1.0               1199.0           14            12             9
# ...         ...                  ...          ...           ...           ...
# 8364        2.0               2982.0           19            11             9
# 8365        2.0               1586.0           16            12             9
# 8366        2.0               1198.0           12            10             9
# 8367        1.0               1396.0           19            11             9
# 8368        2.0               1197.0           15            11             9
#
#       Ownership_encoded  num_Exterior  num_Features   OEM_encoded  \
# 0                     1            17             9  1.449777e+06
# 1                     1             4             8  5.048179e+05
# 2                     1            20             9  5.771039e+05
# 3                     1             6             9  6.060770e+05
# 4                     1            13             9  6.244477e+05
# ...                 ...           ...           ...           ...
# 8364                  3            12             9  1.389006e+06
# 8365                  3             6             9  5.048557e+05
# 8366                  3             6             9  6.245924e+05
# 8367                  1            11             9  6.058636e+05
# 8368                  3            14             9  6.059091e+05
#
#              model
# 0     1.121861e+06
# 1     4.000476e+05
# 2     7.737000e+05
# 3     2.508681e+05
# 4     5.819279e+05
# ...            ...
# 8364  2.091814e+06
# 8365  1.827778e+05
# 8366  3.369672e+05
# 8367  5.620939e+05
# 8368  4.710039e+05
#
# [8369 rows x 18 columns]

# %%
y
# Out:
# 0       1150000.0
# 1        415000.0
# 2        750000.0
# 3        398000.0
# 4        550000.0
#           ...
# 8364    1649000.0
# 8365     330000.0
# 8366     425000.0
# 8367     750000.0
# 8368     675000.0
# Name: Price of the used car, Length: 8369, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# Assuming X and y are already defined
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=70)

# %%
print(X_train.shape,X_test.shape,y_train.shape,y_test.shape)
# Out:
# (6695, 18) (1674, 18) (6695,) (1674,)

# %%
X_train
# Out:
#       fuel type  Body type  Kilometers driven  Transmission type  \
# 1122          0        0.0              89000                  0
# 2270          0        0.0              50000                  0
# 3613          1        2.0              40000                  0
# 2826          1        0.0              98700                  1
# 1254          0        2.0              30000                  0
# ...         ...        ...                ...                ...
# 7150          0        0.0              40000                  0
# 5461          0        2.0              20000                  0
# 5179          1        2.0             104782                  0
# 5234          0        0.0              50000                  1
# 7502          0        0.0              79068                  0
#
#       Number of previous owners  Location  Insurance Validity  Seats  \
# 1122                          1         0                 1.0    5.0
# 2270                          2         1                 0.0    5.0
# 3613                          1         3                 1.0    5.0
# 2826                          2         1                 0.0    5.0
# 1254                          1         0                 0.0    5.0
# ...                         ...       ...                 ...    ...
# 7150                          2         2                 0.0    5.0
# 5461                          1         5                 0.0    5.0
# 5179                          1         5                 4.0    5.0
# 5234                          2         5                 0.0    5.0
# 7502                          1         2                 1.0    5.0
#
#       Ownership  Engine Displacement  num_Comfort  num_Interior  num_features  \
# 1122        1.0               1197.0           13            10             9
# 2270        2.0                998.0           11            10             9
# 3613        1.0               1498.0           16            11             9
# 2826        2.0               1248.0           12            10             9
# 1254        1.0               1462.0           13             8             9
# ...         ...                  ...          ...           ...           ...
# 7150        2.0                998.0           11            10             9
# 5461        1.0               1197.0           20            11             9
# 5179        1.0               1582.0           27            13             9
# 5234        2.0                998.0            8             8             9
# 7502        1.0               1197.0           11             7             9
#
#       Ownership_encoded  num_Exterior  num_Features    OEM_encoded  \
# 1122                  1             6             9  504811.245224
# 2270                  3            11             9  504860.112394
# 3613                  1            10             9  725512.903226
# 2826                  3            11             9  504755.714349
# 1254                  1            10             9  504602.449134
# ...                 ...           ...           ...            ...
# 7150                  3            11             9  504831.236339
# 5461                  1            11             9  605815.152121
# 5179                  1            10             9  605772.727879
# 5234                  3             5             9  504846.784984
# 7502                  1             7             9  504787.700133
#
#               model
# 1122  504928.366762
# 2270  345978.702811
# 3613  435812.500000
# 2826  535847.457627
# 1254  695653.543307
# ...             ...
# 7150  345717.658635
# 5461  710500.000000
# 5179  721419.889503
# 5234  306602.409639
# 7502  504776.504298
#
# [6695 rows x 18 columns]

# %%
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
import xgboost as xgb

# %% [markdown]
# **Linear Regression**

# %%
from sklearn.linear_model import LinearRegression

# Initialize the Linear Regression model
linear_model = LinearRegression(fit_intercept=True)

# Fit the model to the training data
linear_model.fit(X_train, y_train)

# Predict on the test data
predictions = linear_model.predict(X_test)

# Print the predictions and the actual values
print("Predictions:", predictions)
print("Actual values:", y_test)
# Out:
# Predictions: [  17926.52459571  576194.35743641  254941.57538406 ...  254242.41837589
#  2301441.44060446  393754.5393632 ]
# Actual values: 2660     155000.0
# 6181     395000.0
# 806      393000.0
# 5820     824000.0
# 258      720000.0
#           ...
# 7446     825000.0
# 8000    1585000.0
# 2212     294000.0
# 6067    1640000.0
# 7970     428000.0
# Name: Price, Length: 1674, dtype: float64

# %%
linear_model.score(X_test, y_test)
# Out:
# 0.8185368970624962

# %%
from sklearn.model_selection import cross_val_score

# Calculate cross-validation score for the linear regression model
cross_val_linear_model = cross_val_score(linear_model, X_train, y_train, cv=10).mean()

# Print the mean cross-validation score
print("Mean Cross-Validation Score (Linear Model):", cross_val_linear_model)
# Out:
# Mean Cross-Validation Score (Linear Model): 0.6358716142185271

# %% [markdown]
# **K Nearest Neighbor Regression**

# %%
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import cross_val_score
import numpy as np

# Initialize the StandardScaler
scaler = StandardScaler()

# Fit the scaler to the training data and transform it
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Define the range of k values
knn_values = np.arange(1, 50)
cross_val_knn = []

# Iterate through different k values
for k in knn_values:
    # Initialize KNeighborsRegressor with k neighbors
    knn_regressor = KNeighborsRegressor(n_neighbors=k)

    # Fit the KNN regressor to the scaled training data
    knn_regressor.fit(X_train_scaled, y_train)

    # Calculate the training score
    train_score = knn_regressor.score(X_train_scaled, y_train)

    # Calculate the cross-validation score
    cv_score = cross_val_score(knn_regressor, X_train_scaled, y_train, cv=10).mean()

    # Print the scores
    print("K value:", k, "Train score:", train_score, "Cross-validation score:", cv_score)

    # Append the cross-validation score to the list
    cross_val_knn.append(cv_score)
# Out:
# K value: 1 Train score: 1.0 Cross-validation score: 0.6721598219269198
# K value: 2 Train score: 0.904568321616902 Cross-validation score: 0.689516759811299
# K value: 3 Train score: 0.8427848800339675 Cross-validation score: 0.7043153905747269
# K value: 4 Train score: 0.8040179894175521 Cross-validation score: 0.709100572001568
# K value: 5 Train score: 0.7823122660125215 Cross-validation score: 0.6996678218829964
# K value: 6 Train score: 0.7596587700556093 Cross-validation score: 0.6925231258292291
# K value: 7 Train score: 0.7384492014442815 Cross-validation score: 0.6897606423737327
# K value: 8 Train score: 0.7220699534384716 Cross-validation score: 0.687389100664231
# K value: 9 Train score: 0.7121838062668734 Cross-validation score: 0.6872715713998409
# K value: 10 Train score: 0.7012869839368827 Cross-validation score: 0.6827525103054579
# K value: 11 Train score: 0.6903826654665093 Cross-validation score: 0.679018146430612
# K value: 12 Train score: 0.6829043942002762 Cross-validation score: 0.6756315536864177
# K value: 13 Train score: 0.675912445169518 Cross-validation score: 0.6743883110692397
# K value: 14 Train score: 0.6705683993558549 Cross-validation score: 0.6717720193548041
# K value: 15 Train score: 0.6668275497885691 Cross-validation score: 0.6741324122257821
# K value: 16 Train score: 0.6616086476688012 Cross-validation score: 0.6776809685475598
# K value: 17 Train score: 0.658969869032559 Cross-validation score: 0.6749043637526083
# K value: 18 Train score: 0.6544615230046612 Cross-validation score: 0.6745069725056875
# K value: 19 Train score: 0.6542262581405618 Cross-validation score: 0.6723881390995518
# K value: 20 Train score: 0.6508343477580056 Cross-validation score: 0.6744890129276951
# K value: 21 Train score: 0.6512249320780852 Cross-validation score: 0.6731603225608092
# K value: 22 Train score: 0.653068862075215 Cross-validation score: 0.6721565294626659
# K value: 23 Train score: 0.6488907951477421 Cross-validation score: 0.6718307295555088
# K value: 24 Train score: 0.6457174906643118 Cross-validation score: 0.6709610132947634
# K value: 25 Train score: 0.6442018190525692 Cross-validation score: 0.6691917171613977
# K value: 26 Train score: 0.6423598235003467 Cross-validation score: 0.6672353728822744
# K value: 27 Train score: 0.6407861619832717 Cross-validation score: 0.6660139347549998
# K value: 28 Train score: 0.638260084832639 Cross-validation score: 0.6647861903954656
# K value: 29 Train score: 0.6358238403700798 Cross-validation score: 0.6645211620157336
# K value: 30 Train score: 0.6328009203716334 Cross-validation score: 0.6631747901894597
# K value: 31 Train score: 0.6312992979699794 Cross-validation score: 0.6621733452173961
# K value: 32 Train score: 0.6295825539920206 Cross-validation score: 0.6635716222173249
# K value: 33 Train score: 0.6274175969686346 Cross-validation score: 0.662066741271605
# K value: 34 Train score: 0.625269611387844 Cross-validation score: 0.6601158322627835
# K value: 35 Train score: 0.6253576436156308 Cross-validation score: 0.6595028300177227
# K value: 36 Train score: 0.6236593890780178 Cross-validation score: 0.6591161367960533
# K value: 37 Train score: 0.6225817914229494 Cross-validation score: 0.6585422503711096
# K value: 38 Train score: 0.621575234281625 Cross-validation score: 0.658128991523428
# K value: 39 Train score: 0.6200209488712887 Cross-validation score: 0.6583842111115495
# K value: 40 Train score: 0.618372782422095 Cross-validation score: 0.657879255282744
# K value: 41 Train score: 0.6177245424912263 Cross-validation score: 0.6570785295873436
# K value: 42 Train score: 0.6166585609414998 Cross-validation score: 0.6570302927862036
# K value: 43 Train score: 0.6150107389757498 Cross-validation score: 0.656464513632627
# K value: 44 Train score: 0.6150238951719085 Cross-validation score: 0.6553680724725128
# K value: 45 Train score: 0.6140137072396885 Cross-validation score: 0.6547967579359573
# K value: 46 Train score: 0.6144517050435572 Cross-validation score: 0.6538940568266741
# K value: 47 Train score: 0.6133560407355991 Cross-validation score: 0.6535618714814457
# K value: 48 Train score: 0.6126712861175179 Cross-validation score: 0.6531156565108516
# K value: 49 Train score: 0.6119559052823671 Cross-validation score: 0.6527916367907801

# %%
cross_val_knn_regressor=max(cross_val_knn)
print("The best K-Value is 4 and Cross_val_score is",cross_val_knn_regressor )
# Out:
# The best K-Value is 4 and Cross_val_score is 0.709100572001568

# %%
# Initialize K Nearest Neighbor Regression with 3 neighbors
knn_regressor = KNeighborsRegressor(n_neighbors=3)

# Fit the KNN regressor to the scaled training data
knn_regressor.fit(X_train_scaled, y_train)
# Out:
# KNeighborsRegressor(n_neighbors=3)

# %%
from sklearn.model_selection import cross_val_score

# Compute the cross-validation score for knn_regressor
cross_val_knn_regressor = cross_val_score(knn_regressor, X_train_scaled, y_train, cv=15).mean()

# Print the cross-validation score
print("Cross-validation score for KNN Regression:", cross_val_knn_regressor)
# Out:
# Cross-validation score for KNN Regression: 0.7002788515090022

# %% [markdown]
# **Random Forest Regression**

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import cross_val_score
import numpy as np

# Define the range of max_depth values to try
max_depth = np.array([2, 4, 8, 10, 11, 12, 13, 15, 18, 20])

# Initialize an empty list to store cross-validation scores
cross_val_rf = []

# Iterate through different max_depth values
for d in max_depth:
    # Initialize RandomForestRegressor with the current max_depth value
    rf_regressor = RandomForestRegressor(max_depth=d, random_state=0)

    # Fit the RandomForestRegressor to the training data
    rf_regressor.fit(X_train, y_train)

    # Calculate the cross-validation score
    cv_score = cross_val_score(rf_regressor, X_train, y_train, cv=15).mean()

    # Print the depth and cross-validation score
    print("Depth:", d, "Cross-validation score:", cv_score)

    # Append the cross-validation score to the list
    cross_val_rf.append(cv_score)
# Out:
# Depth: 2 Cross-validation score: 0.5591172702788819
# Depth: 4 Cross-validation score: 0.6712769629204886
# Depth: 8 Cross-validation score: 0.736069114525885
# Depth: 10 Cross-validation score: 0.7535068926015408
# Depth: 11 Cross-validation score: 0.7567918145770545
# Depth: 12 Cross-validation score: 0.7600356699785468
# Depth: 13 Cross-validation score: 0.7636714283825615
# Depth: 15 Cross-validation score: 0.7607670316011512
# Depth: 18 Cross-validation score: 0.7653867685967708
# Depth: 20 Cross-validation score: 0.7628135402157452

# %%
cross_val_rf_regressor = max(cross_val_rf)

# %%
print("The best depth is 18 and Cross_val_score is:",cross_val_rf_regressor)
# Out:
# The best depth is 18 and Cross_val_score is: 0.7653867685967708

# %%
from sklearn.ensemble import RandomForestRegressor

# Initialize a RandomForestRegressor with max_depth=18 and random_state=0
rf_regressor = RandomForestRegressor(max_depth=18, random_state=0)

# Fit the RandomForestRegressor to the training data
rf_regressor.fit(X_train, y_train)
# Out:
# RandomForestRegressor(max_depth=18, random_state=0)

# %%
from sklearn.model_selection import cross_val_score

# Compute the cross-validation score for rf_regressor
cross_val_rf_regressor = cross_val_score(rf_regressor, X_train, y_train, cv=15).mean()

# Print or use the cross-validation score
print("Cross-validation score for RandomForestRegressor:", cross_val_rf_regressor)
# Out:
# Cross-validation score for RandomForestRegressor: 0.7653867685967708

# %% [markdown]
# **Extreme Gradient Boosting Regression**

# %%
import xgboost as xgb
from sklearn.model_selection import cross_val_score

# Initialize an empty list to store cross-validation scores
cross_val_xgb = []

# Iterate through different learning rates
for lr in [0.01, 0.05, 0.08, 0.1, 0.2, 0.25, 0.3]:
    # Initialize XGBoost regressor with the current learning rate
    xgb_regressor = xgb.XGBRegressor(learning_rate=lr, n_estimators=100)

    # Fit the XGBoost regressor to the training data
    xgb_regressor.fit(X_train, y_train)

    # Calculate the cross-validation score
    cv_score = cross_val_score(xgb_regressor, X_train, y_train, cv=15).mean()

    # Print the learning rate and cross-validation score
    print("Learning rate:", lr, "Cross-validation score:", cv_score)

    # Append the cross-validation score to the list
    cross_val_xgb.append(cv_score)
# Out:
# Learning rate: 0.01 Cross-validation score: 0.5844444548163039
# Learning rate: 0.05 Cross-validation score: 0.6617106101582263
# Learning rate: 0.08 Cross-validation score: 0.6659998186654955
# Learning rate: 0.1 Cross-validation score: 0.6776681602589533
# Learning rate: 0.2 Cross-validation score: 0.6621831646747041
# Learning rate: 0.25 Cross-validation score: 0.6946269216027275
# Learning rate: 0.3 Cross-validation score: 0.6921185531342484

# %%
cross_val_xgb_regressor = max(cross_val_xgb)

# %%
print("The best Learning rate is 0.25 and Cross_val_score is:",cross_val_xgb_regressor)
# Out:
# The best Learning rate is 0.25 and Cross_val_score is: 0.6946269216027275

# %%
xgb_regressor= xgb.XGBRegressor(learning_rate =0.25,n_estimators=100) # initialise the model
xgb_regressor.fit(X_train,y_train) #train the model
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.25, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=100, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %% [markdown]
# **Cross-Validation Score for Machine-Learning Models**

# %%
print("Cross Validation Score for Linear Regression Model:", cross_val_linear_model)
print("Cross Validation Score for K-Nearest Neighbors Regression Model:", cross_val_knn_regressor)
print("Cross Validation Score for Random Forest Regression Model:", cross_val_rf_regressor)
print("Cross Validation Score for Extreme-Gradient Boosting Regression Model:", cross_val_xgb_regressor)
# Out:
# Cross Validation Score for Linear Regression Model: 0.6358716142185271
# Cross Validation Score for K-Nearest Neighbors Regression Model: 0.7002788515090022
# Cross Validation Score for Random Forest Regression Model: 0.7653867685967708
# Cross Validation Score for Extreme-Gradient Boosting Regression Model: 0.6946269216027275

# %% [markdown]
# **R2 Score for Machine-Learning Models**

# %%
from sklearn.metrics import r2_score

# %%
# Predictions using Linear Regression
y_pred_lr = linear_model.predict(X_test)

# Predictions using K-Nearest Neighbors Regression
y_pred_knn = knn_regressor.predict(X_test)

# Predictions using Random Forest Regression
y_pred_rf = rf_regressor.predict(X_test)

# Predictions using Extreme-Gradient Boosting Regression
y_pred_xgb = xgb_regressor.predict(X_test)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:432: UserWarning: X has feature names, but KNeighborsRegressor was fitted without feature names
#   warnings.warn(

# %%
from sklearn.metrics import r2_score

# R-squared score for Linear Regression
R2_score_lr = r2_score(y_test, y_pred_lr)

# R-squared score for K-Nearest Neighbors Regression
R2_score_knn = r2_score(y_test, y_pred_knn)

# R-squared score for Random Forest Regression
R2_score_rf = r2_score(y_test, y_pred_rf)

# R-squared score for Extreme-Gradient Boosting Regression
R2_score_xgb = r2_score(y_test, y_pred_xgb)

# %%
print("R2 Score for Linear Regression Model:", R2_score_lr)
print("R2 Score for K-Nearest Neighbors Regression Model:", R2_score_knn)
print("R2 Score for Random Forest Regression Model:", R2_score_rf)
print("R2 Score for Extreme-Gradient Boosting Regression Model:", R2_score_xgb)
# Out:
# R2 Score for Linear Regression Model: 0.8185368970624962
# R2 Score for K-Nearest Neighbors Regression Model: -158.7072933230086
# R2 Score for Random Forest Regression Model: 0.8851250943075151
# R2 Score for Extreme-Gradient Boosting Regression Model: 0.7873369194843731

# %%
sorted_idx = xgb_regressor.feature_importances_.argsort()

plt.figure(figsize=(10,5))
plt.barh(data.columns[sorted_idx], xgb_regressor.feature_importances_[sorted_idx])
plt.xlabel("XGBoost Feature Importance")
plt.title("Feature Importance")
plt.show()
